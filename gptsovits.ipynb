# %% [markdown]
# refer https://www.bilibili.com/video/BV1Ap4y1U7jW
# homepage https://github.com/RVC-Boss/GPT-SoVITS

# %%
env_CN=0
if env_CN==1:
    git config --global url."https://mirror.ghproxy.com/https://github.com/".insteadOf https://github.com/
    export HF_ENDPOINT=https://hf-mirror.com
    # export HF_ENDPOINT=https://hf-api.gitee.com

# %%
# !nvcc --version
# !nvidia-smi

# %% [markdown]
# 环境配置 environment

# %%
# %cd -q /kaggle/working/
# !git clone https://github.com/RVC-Boss/GPT-SoVITS
# %cd -q /kaggle/working/GPT-SoVITS
# !pip install -r requirements.txt

# %% [markdown]
# # @title Download pretrained models 下载预训练模型

# %%
# %cd /kaggle/working/GPT-SoVITS/tools/asr/models
# !git clone https://www.modelscope.cn/damo/speech_paraformer-large_asr_nat-zh-cn-16k-common-vocab8404-pytorch.git
# !git clone https://www.modelscope.cn/damo/speech_fsmn_vad_zh-cn-16k-common-pytorch.git
# !git clone https://www.modelscope.cn/damo/punc_ct-transformer_zh-cn-common-vocab272727-pytorch.git

# %% [markdown]
# ## update

# %%
# repalce with huggingface_hub below
# %cd /kaggle/working/GPT-SoVITS
# !git pull
# %cd /kaggle/working/GPT-SoVITS/tools/asr/models/speech_paraformer-large_asr_nat-zh-cn-16k-common-vocab8404-pytorch
# !git pull
# !git-lfs pull
# %cd /kaggle/working/GPT-SoVITS/tools/asr/models/speech_fsmn_vad_zh-cn-16k-common-pytorch
# !git pull
# !git-lfs pull
# %cd /kaggle/working/GPT-SoVITS/tools/asr/models/punc_ct-transformer_zh-cn-common-vocab272727-pytorch
# !git pull
# !git-lfs pull

# %%
from huggingface_hub import snapshot_download, hf_hub_download
# !pip install modelscope
from modelscope.hub.snapshot_download import snapshot_download

import os
snapshot_download(repo_id="lj1995/GPT-SoVITS", local_dir="/kaggle/working/GPT-SoVITS/GPT_SoVITS/pretrained_models")
# v2
# !wget https://paddlespeech.bj.bcebos.com/Parakeet/released_models/g2p/G2PWModel_1.1.zip -P /opt/
# !unzip /opt/G2PWModel_1.1.zip -d /opt
# !mv /opt/G2PWModel_1.1 /kaggle/working/GPT-SoVITS/GPT_SoVITS/text/G2PWModel

# @title UVR5 pretrains 安装uvr5模型
snapshot_download(repo_id="lj1995/VoiceConversionWebUI", local_dir="/kaggle/working/GPT-SoVITS/tools/uvr5/uvr5_weights")
snapshot_download(repo_id="openai/whisper-large-v3-turbo",f local_dir="/kaggle/working/GPT-SoVITS/tools/tools/asr/models")

# %% [markdown]
# # reboot

# %%
env_CN=0
if env_CN==1:
    git config --global url."https://mirror.ghproxy.com/https://github.com/".insteadOf https://github.com/
    export HF_ENDPOINT=https://hf-mirror.com
    # export HF_ENDPOINT=https://hf-api.gitee.com

# %%
# !nvcc --version
# !nvidia-smi 
# !pip list|grep transformers
# !pip list|grep numpy
# !pip list|grep numba

# %%
# %cd /kaggle/working/GPT-SoVITS
# !pip install ipykernel
# !pip install -r requirements.txt
# !pip install pyngrok
# !npm install -g localtunnel
# %cd -q /kaggle/working/GPT-SoVITS/GPT_SoVITS/pretrained_models
# !ln -s GPT-SoVITS/* .

# %% [markdown]
# ### clear

# %%
# %cd /kaggle/working/GPT-SoVITS
# !mkdir -p ./output/hunan_girl/slicer
# !mkdir -p ./output/hunan_girl/asr
# !rm ./output/uvr5_opt/*

# %% [markdown]
# ## 推理webui

# %%
# %cd /kaggle/working/GPT-SoVITS
import subprocess
import urllib.request
from IPython.display import clear_output
clear_output()
print("The password/enpoint ip for localtunnel is:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
print("tts_tunnel is:")
subprocess.Popen(["lt", "--port", "9872"])
# !python GPT_SoVITS/inference_webui.py

# %% [markdown]
# ## uvr5 webui

# %%
# %cd /kaggle/working/GPT-SoVITS
import subprocess
import urllib.request
from IPython.display import clear_output
clear_output()
print("The password/enpoint ip for localtunnel is:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
subprocess.Popen(["lt", "--port", "9873"])
# cmd = '"%s" tools/uvr5/webui.py "%s" %s %s %s'%(python_exec,infer_device,is_half,webui_port_uvr5,is_share)
# !python -m tools/uvr5/webui.py "cuda" False 9873 False

# %%
# %cd /kaggle/working/GPT-SoVITS
import subprocess
import urllib.request
from IPython.display import clear_output
clear_output()
print("The password/enpoint ip for localtunnel is:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
subprocess.Popen(["lt", "--port", "9873"])
# cmd = '"%s" tools/uvr5/webui.py "%s" %s %s %s'%(python_exec,infer_device,is_half,webui_port_uvr5,is_share)
# !python -m tools/uvr5/webui.py "cuda" False 9873 False

# %% [markdown]
# ## 训练webui

# %%
# %cd /kaggle/working/GPT-SoVITS
import subprocess
import urllib.request
from IPython.display import clear_output
clear_output()
print("The password/enpoint ip for localtunnel is:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
print("main_tunnel is:")
subprocess.Popen(["lt", "--port", "9874"])
print("uvr5_tunnel is:")
subprocess.Popen(["lt", "--port", "9873"])
print("tts_tunnel is:")
subprocess.Popen(["lt", "--port", "9872"])
# !python  webui.py
