# %% [markdown]
# cpu is free time

# %% [markdown]
# ## local server
#
# follow is disable
# - gradio
# - ngrok
# - cloudflared
#
# can use
# - localtunrnl

# %% [markdown]
# ## data
# only `/kaggle/working/*` will save.
# so env like `apt install` and `pip install` not save

# %% [markdown]
# ## forbiden
# blow behavice will be baned
# - use facefusion,or download form facefusion

# %% [markdown]
# ## snippets

# %%
env_CN=0
if env_CN==1:
    git config --global url."https://mirror.ghproxy.com/https://github.com/".insteadOf https://github.com/
    export HF_ENDPOINT=https://hf-mirror.com
    # export HF_ENDPOINT=https://hf-api.gitee.com

# %%
# !nvcc --version
# !nvidia-smi 

# !pip list |grep numba
# !pip list |grep numpy
# !pip list |grep transformers
