# %%
# !nvcc --version
# !nvidia-smi

# %%
env_CN=0
if env_CN==1:
    git config --global url."https://mirror.ghproxy.com/https://github.com/".insteadOf https://github.com/
    export HF_ENDPOINT=https://hf-mirror.com
    # export HF_ENDPOINT=https://hf-api.gitee.com

# %%
# !git clone https://github.com/KwaiVGI/LivePortrait
# %cd LivePortrait
# !pip install -r requirements.txt

# %%
# %cd /kaggle/working/LivePortrait
# !huggingface-cli download KwaiVGI/LivePortrait --local-dir pretrained_weights --exclude "*.git*" "README.md" "docs"
# Out:
# /kaggle/working/LivePortrait
# Fetching 16 files:   0%|                                 | 0/16 [00:00<?, ?it/s]Downloading 'liveportrait/base_models/appearance_feature_extractor.pth' to 'pretrained_weights/.cache/huggingface/download/liveportrait/base_models/appearance_feature_extractor.pth.5279bb8654293dbdf327030b397f107237dd9212fb11dd75b83dfb635211ceb5.incomplete'
# ...
#
# showcase2.gif:   0%|                                | 0.00/2.88M [00:00<?, ?B/s]
#
# det_10g.onnx:   0%|                                 | 0.00/16.9M [00:00<?, ?B/s]
#
#
# inference.gif:   0%|                                 | 0.00/820k [00:00<?, ?B/s]
#
#
#
# warping_module.pth:   0%|                            | 0.00/182M [00:00<?, ?B/s]
#
#
#
#
# motion_extractor.pth:   0%|                          | 0.00/113M [00:00<?, ?B/s]
#
#
#
#
#
# appearance_feature_extractor.pth:   0%|             | 0.00/3.39M [00:00<?, ?B/s]
#
#
#
#
#
#
# showcase2.gif: 100%|███████████████████████| 2.88M/2.88M [00:00<00:00, 47.0MB/s]
# ...

# %% [markdown]
# ## reboot run it

# %%
# %cd /kaggle/working/LivePortrait
# !git checkout .
# !git pull
# !pip install -r requirements.txt
# Out:
# /kaggle/working/LivePortrait
# Updated 211 paths from the index
# Already up to date.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.2/84.2 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.5/705.5 kB 24.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 43.7 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.5/313.5 kB 20.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.2/299.2 kB 19.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 86.5 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.9/14.9 MB 87.0 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.9/161.9 kB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 96.9 MB/s eta 0:00:00:00:0100:01
# ...

# %%
# %cd /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops
# !python setup.py build install
# %cd ../../../../../../../
# Out:
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops
# /opt/conda/lib/python3.10/site-packages/torch/utils/cpp_extension.py:424: UserWarning: There are no g++ version bounds defined for CUDA version 12.3
#   warnings.warn(f'There are no {compiler_name} version bounds defined for CUDA version {cuda_str_version}')
# /opt/conda/lib/python3.10/site-packages/torch/utils/cpp_extension.py:1965: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# Emitting ninja build file /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/build/temp.linux-x86_64-cpython-310/build.ninja...
# Compiling objects...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ...

# %%
# start webui 
# %cd /kaggle/working/LivePortrait
# !npm install -g localtunnel
# !pip install --upgrade  gradio
import subprocess
import urllib.request
print("The password/enpoint ip for localtunnel is:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
subprocess.Popen(["lt", "--port", "8188"])
# Out:
# /kaggle/working/LivePortrait
# m#################.] \ reify:debug: http fetch GET 200 https://registry.npmjs.o
# added 22 packages in 2s
#
# 3 packages are looking for funding
#   run `npm fund` for details
# npm notice
# npm notice New minor version of npm available! 10.5.0 -> 10.8.3
# npm notice Changelog: https://github.com/npm/cli/releases/tag/v10.8.3
# npm notice Run npm install -g npm@10.8.3 to update!
# npm notice
# The password/enpoint ip for localtunnel is: 35.230.70.162
# <Popen: returncode: None args: ['lt', '--port', '8188']>

# %%
# %cd /kaggle/working/LivePortrait
# !python app.py --no-share --server_port=8188  --flag_do_torch_compile #   humans mode
# !python app_animals.py --no-share --server_port=8188  --flag_do_torch_compile # animals mode
# Out:
# /kaggle/working/LivePortrait
# your url is: https://clever-humans-train.loca.lt
# ...

# %%
# clear
# !rm /kaggle/working/LivePortrait/animations/*
