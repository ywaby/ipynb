# %%
# !nvcc --version
# !nvidia-smi

# %%
# !git clone https://github.com/KwaiVGI/LivePortrait
# %cd LivePortrait
# !pip install -r requirements.txt

# %%
# !pip install huggingface_hub  hf_transfer
import os
os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "1"

# %%
# %cd /kaggle/working/LivePortrait
# !huggingface-cli download KwaiVGI/LivePortrait --local-dir pretrained_weights --exclude "*.git*" "README.md" "docs"
# Out:
# /kaggle/working/LivePortrait
# Fetching 16 files:   0%|                                 | 0/16 [00:00<?, ?it/s]Downloading 'liveportrait/base_models/appearance_feature_extractor.pth' to 'pretrained_weights/.cache/huggingface/download/liveportrait/base_models/appearance_feature_extractor.pth.5279bb8654293dbdf327030b397f107237dd9212fb11dd75b83dfb635211ceb5.incomplete'
# Downloading 'liveportrait/base_models/motion_extractor.pth' to 'pretrained_weights/.cache/huggingface/download/liveportrait/base_models/motion_extractor.pth.251e6a94ad667a1d0c69526d292677165110ef7f0cf0f6d199f0e414e8aa0ca5.incomplete'
# Downloading 'liveportrait/base_models/warping_module.pth' to 'pretrained_weights/.cache/huggingface/download/liveportrait/base_models/warping_module.pth.2f61a6f265fe344f14132364859a78bdbbc2068577170693da57fb96d636e282.incomplete'
# Downloading 'liveportrait/base_models/spade_generator.pth' to 'pretrained_weights/.cache/huggingface/download/liveportrait/base_models/spade_generator.pth.4780afc7909a9f84e24c01d73b31a555ef651521a1fe3b2429bd04534d992aee.incomplete'
# Downloading 'docs/showcase2.gif' to 'pretrained_weights/.cache/huggingface/download/docs/showcase2.gif.eb1fffb139681775780b2956e7d0289f55d199c1a3e14ab263887864d4b0d586.incomplete'
# Downloading 'insightface/models/buffalo_l/det_10g.onnx' to 'pretrained_weights/.cache/huggingface/download/insightface/models/buffalo_l/det_10g.onnx.5838f7fe053675b1c7a08b633df49e7af5495cee0493c7dcf6697200b85b5b91.incomplete'
# Downloading 'docs/inference.gif' to 'pretrained_weights/.cache/huggingface/download/docs/inference.gif.e1316eca5556ba5a8da7c53bcadbc1df26aa822bbde68fbad94813139803d0c6.incomplete'
# Downloading 'insightface/models/buffalo_l/2d106det.onnx' to 'pretrained_weights/.cache/huggingface/download/insightface/models/buffalo_l/2d106det.onnx.f001b856447c413801ef5c42091ed0cd516fcd21f2d6b79635b1e733a7109dbf.incomplete'
#
# showcase2.gif:   0%|                                | 0.00/2.88M [00:00<?, ?B/s]
#
# det_10g.onnx:   0%|                                 | 0.00/16.9M [00:00<?, ?B/s]
#
#
# inference.gif:   0%|                                 | 0.00/820k [00:00<?, ?B/s]
#
#
#
# warping_module.pth:   0%|                            | 0.00/182M [00:00<?, ?B/s]
#
#
#
#
# motion_extractor.pth:   0%|                          | 0.00/113M [00:00<?, ?B/s]
#
#
#
#
#
# appearance_feature_extractor.pth:   0%|             | 0.00/3.39M [00:00<?, ?B/s]
#
#
#
#
#
#
# showcase2.gif: 100%|███████████████████████| 2.88M/2.88M [00:00<00:00, 47.0MB/s]
# Download complete. Moving file to pretrained_weights/docs/showcase2.gif
# inference.gif: 100%|█████████████████████████| 820k/820k [00:00<00:00, 17.3MB/s]
# Download complete. Moving file to pretrained_weights/docs/inference.gif
# Fetching 16 files:   6%|█▌                       | 1/16 [00:00<00:05,  2.82it/s]
# appearance_feature_extractor.pth: 100%|████| 3.39M/3.39M [00:00<00:00, 43.0MB/s]
# Download complete. Moving file to pretrained_weights/liveportrait/base_models/appearance_feature_extractor.pth
#
#
#
#
# warping_module.pth:   6%|█                  | 10.5M/182M [00:00<00:02, 78.5MB/s]
#
#
#
#
# motion_extractor.pth:   9%|█▌               | 10.5M/113M [00:00<00:01, 68.4MB/s]
#
#
#
#
#
#
# spade_generator.pth:   5%|▊                 | 10.5M/222M [00:00<00:03, 69.2MB/s]Downloading 'liveportrait/retargeting_models/stitching_retargeting_module.pth' to 'pretrained_weights/.cache/huggingface/download/liveportrait/retargeting_models/stitching_retargeting_module.pth.3652d5a3f95099141a56986aaddec92fadf0a73c87a20fac9a2c07c32b28b611.incomplete'
#
#
# det_10g.onnx:  62%|██████████████▊         | 10.5M/16.9M [00:00<00:00, 54.8MB/s]Downloading 'liveportrait_animals/base_models/appearance_feature_extractor.pth' to 'pretrained_weights/.cache/huggingface/download/liveportrait_animals/base_models/appearance_feature_extractor.pth.e2cd1d5d67c0457229e9736d401d39225e096895b869f34234978082561af6de.incomplete'
# Downloading 'liveportrait/landmark.onnx' to 'pretrained_weights/.cache/huggingface/download/liveportrait/landmark.onnx.31d22a5041326c31f19b78886939a634a5aedcaa5ab8b9b951a1167595d147db.incomplete'
#
# 2d106det.onnx: 100%|███████████████████████| 5.03M/5.03M [00:00<00:00, 35.4MB/s]
# Download complete. Moving file to pretrained_weights/insightface/models/buffalo_l/2d106det.onnx
# det_10g.onnx: 100%|████████████████████████| 16.9M/16.9M [00:00<00:00, 63.9MB/s]
# Download complete. Moving file to pretrained_weights/insightface/models/buffalo_l/det_10g.onnx
#
#
#
#
# warping_module.pth:  12%|██▏                | 21.0M/182M [00:00<00:02, 76.6MB/s]
#
#
#
#
# motion_extractor.pth:  19%|███▏             | 21.0M/113M [00:00<00:01, 75.8MB/s]
# stitching_retargeting_module.pth:   0%|             | 0.00/2.39M [00:00<?, ?B/s]
#
#
#
#
#
#
# spade_generator.pth:   9%|█▋                | 21.0M/222M [00:00<00:02, 70.7MB/s]
#
# landmark.onnx:   0%|                                 | 0.00/115M [00:00<?, ?B/s]
#
#
# appearance_feature_extractor.pth:   0%|             | 0.00/3.39M [00:00<?, ?B/s]Downloading 'liveportrait_animals/base_models/motion_extractor.pth' to 'pretrained_weights/.cache/huggingface/download/liveportrait_animals/base_models/motion_extractor.pth.63c0d450099ef6ebece788ab711cb012509712e23fd1200b79fb65ef980adbb9.incomplete'
# stitching_retargeting_module.pth: 100%|████| 2.39M/2.39M [00:00<00:00, 84.3MB/s]
# Download complete. Moving file to pretrained_weights/liveportrait/retargeting_models/stitching_retargeting_module.pth
# appearance_feature_extractor.pth: 100%|████| 3.39M/3.39M [00:00<00:00, 70.3MB/s]
# Download complete. Moving file to pretrained_weights/liveportrait_animals/base_models/appearance_feature_extractor.pth
#
#
#
#
# warping_module.pth:  17%|███▎               | 31.5M/182M [00:00<00:01, 86.8MB/s]Downloading 'liveportrait_animals/base_models/spade_generator.pth' to 'pretrained_weights/.cache/huggingface/download/liveportrait_animals/base_models/spade_generator.pth.7fafa1e31c7c72c9384310d679e32af3fbf214e241fb657df8c3b18ad826f336.incomplete'
#
#
#
#
#
# motion_extractor.pth:  28%|████▊            | 31.5M/113M [00:00<00:00, 81.7MB/s]
#
#
#
#
#
#
# spade_generator.pth:  14%|██▌               | 31.5M/222M [00:00<00:02, 80.9MB/s]
#
# landmark.onnx:   9%|██▏                     | 10.5M/115M [00:00<00:01, 82.2MB/s]Downloading 'liveportrait_animals/base_models/warping_module.pth' to 'pretrained_weights/.cache/huggingface/download/liveportrait_animals/base_models/warping_module.pth.c9719ea184ca9da059f4eee8a8c8c7c6bd46a2b1e40a241ea5490cc42ce6b79b.incomplete'
#
# motion_extractor.pth:   0%|                          | 0.00/113M [00:00<?, ?B/s]Downloading 'liveportrait_animals/retargeting_models/stitching_retargeting_module.pth' to 'pretrained_weights/.cache/huggingface/download/liveportrait_animals/retargeting_models/stitching_retargeting_module.pth.3652d5a3f95099141a56986aaddec92fadf0a73c87a20fac9a2c07c32b28b611.incomplete'
#
#
#
# spade_generator.pth:   0%|                           | 0.00/222M [00:00<?, ?B/s]
#
#
#
#
#
# stitching_retargeting_module.pth:   0%|             | 0.00/2.39M [00:00<?, ?B/s]
#
#
#
#
# stitching_retargeting_module.pth: 100%|████| 2.39M/2.39M [00:00<00:00, 87.3MB/s]
# Download complete. Moving file to pretrained_weights/liveportrait_animals/retargeting_models/stitching_retargeting_module.pth
#
#
#
#
#
#
#
# spade_generator.pth:  19%|███▍              | 41.9M/222M [00:00<00:02, 81.8MB/s]
#
#
#
# warping_module.pth:  29%|█████▊              | 52.4M/182M [00:00<00:01, 104MB/s]
#
# landmark.onnx:  18%|████▍                   | 21.0M/115M [00:00<00:01, 75.4MB/s]
#
#
#
#
#
# warping_module.pth:   0%|                            | 0.00/182M [00:00<?, ?B/s]
# motion_extractor.pth:   9%|█▌               | 10.5M/113M [00:00<00:01, 61.5MB/s]Downloading 'liveportrait_animals/xpose.pth' to 'pretrained_weights/.cache/huggingface/download/liveportrait_animals/xpose.pth.bf58e5a3c4a3a017198edc69e33f89c9a37adc856fe6b1776059b2d4a524a7dd.incomplete'
#
#
#
# spade_generator.pth:   5%|▊                 | 10.5M/222M [00:00<00:03, 61.3MB/s]
#
#
#
#
# motion_extractor.pth:  47%|███████▉         | 52.4M/113M [00:00<00:00, 77.9MB/s]
#
#
#
#
#
#
# spade_generator.pth:  24%|████▎             | 52.4M/222M [00:00<00:02, 75.1MB/s]
#
#
#
# warping_module.pth:  35%|██████▌            | 62.9M/182M [00:00<00:01, 87.2MB/s]
#
#
#
#
#
# warping_module.pth:   6%|█                  | 10.5M/182M [00:00<00:02, 68.8MB/s]
#
#
#
#
#
#
#
# xpose.pth:   0%|                                     | 0.00/435M [00:00<?, ?B/s]
#
# landmark.onnx:  27%|██████▌                 | 31.5M/115M [00:00<00:01, 67.6MB/s]
# motion_extractor.pth:  19%|███▏             | 21.0M/113M [00:00<00:01, 64.8MB/s]
#
#
# spade_generator.pth:   9%|█▋                | 21.0M/222M [00:00<00:03, 61.1MB/s]
#
#
#
#
# motion_extractor.pth:  56%|█████████▌       | 62.9M/113M [00:00<00:00, 69.9MB/s]
#
#
#
#
#
#
# spade_generator.pth:  28%|█████             | 62.9M/222M [00:00<00:02, 68.6MB/s]
#
#
#
# warping_module.pth:  40%|███████▋           | 73.4M/182M [00:00<00:01, 78.0MB/s]
#
#
#
#
#
# warping_module.pth:  12%|██▏                | 21.0M/182M [00:00<00:02, 63.2MB/s]
#
#
#
#
#
#
#
# xpose.pth:   2%|▋                           | 10.5M/435M [00:00<00:07, 56.4MB/s]
#
# landmark.onnx:  37%|████████▊               | 41.9M/115M [00:00<00:01, 62.9MB/s]
# motion_extractor.pth:  28%|████▊            | 31.5M/113M [00:00<00:01, 60.8MB/s]
#
#
# spade_generator.pth:  14%|██▌               | 31.5M/222M [00:00<00:03, 61.8MB/s]
#
#
#
#
# motion_extractor.pth:  65%|███████████      | 73.4M/113M [00:01<00:00, 65.4MB/s]
#
#
#
# warping_module.pth:  46%|████████▋          | 83.9M/182M [00:01<00:01, 73.6MB/s]
#
#
#
#
#
#
# spade_generator.pth:  33%|█████▉            | 73.4M/222M [00:01<00:02, 65.3MB/s]
#
#
#
#
#
# warping_module.pth:  17%|███▎               | 31.5M/182M [00:00<00:02, 62.6MB/s]
#
#
#
#
#
#
#
# xpose.pth:   5%|█▎                          | 21.0M/435M [00:00<00:07, 57.7MB/s]
#
# landmark.onnx:  46%|██████████▉             | 52.4M/115M [00:00<00:01, 62.1MB/s]
# motion_extractor.pth:  37%|██████▎          | 41.9M/113M [00:00<00:01, 62.4MB/s]
#
#
# spade_generator.pth:  19%|███▍              | 41.9M/222M [00:00<00:02, 62.4MB/s]
#
#
#
#
# motion_extractor.pth:  75%|████████████▋    | 83.9M/113M [00:01<00:00, 68.2MB/s]
#
#
#
#
#
#
# spade_generator.pth:  38%|██████▊           | 83.9M/222M [00:01<00:02, 67.0MB/s]
#
#
#
# warping_module.pth:  52%|█████████▊         | 94.4M/182M [00:01<00:01, 70.9MB/s]
#
# landmark.onnx:  55%|█████████████▏          | 62.9M/115M [00:00<00:00, 66.2MB/s]
#
#
#
#
#
# warping_module.pth:  23%|████▎              | 41.9M/182M [00:00<00:02, 60.9MB/s]
#
#
#
#
#
#
#
# xpose.pth:   7%|██                          | 31.5M/435M [00:00<00:06, 59.0MB/s]
# motion_extractor.pth:  47%|███████▉         | 52.4M/113M [00:00<00:00, 61.7MB/s]
#
#
# spade_generator.pth:  24%|████▎             | 52.4M/222M [00:00<00:02, 64.4MB/s]
#
#
#
#
# motion_extractor.pth:  84%|██████████████▎  | 94.4M/113M [00:01<00:00, 66.4MB/s]
#
#
#
# warping_module.pth:  58%|███████████▌        | 105M/182M [00:01<00:01, 71.7MB/s]
#
#
#
#
#
#
# spade_generator.pth:  43%|███████▋          | 94.4M/222M [00:01<00:01, 67.2MB/s]
#
# landmark.onnx:  64%|███████████████▎        | 73.4M/115M [00:01<00:00, 67.9MB/s]
#
#
#
#
#
#
#
# xpose.pth:  10%|██▋                         | 41.9M/435M [00:00<00:06, 64.5MB/s]
#
#
#
#
#
# warping_module.pth:  29%|█████▍             | 52.4M/182M [00:00<00:02, 61.5MB/s]
# motion_extractor.pth:  56%|█████████▌       | 62.9M/113M [00:01<00:00, 62.2MB/s]
#
#
# spade_generator.pth:  28%|█████             | 62.9M/222M [00:00<00:02, 65.7MB/s]
#
#
#
#
# motion_extractor.pth:  93%|████████████████▊ | 105M/113M [00:01<00:00, 65.3MB/s]
#
#
#
# warping_module.pth:  63%|████████████▋       | 115M/182M [00:01<00:00, 69.4MB/s]
#
#
#
#
#
#
# spade_generator.pth:  47%|████████▉          | 105M/222M [00:01<00:01, 66.2MB/s]
#
#
#
#
#
#
#
# xpose.pth:  12%|███▎                        | 52.4M/435M [00:00<00:05, 71.4MB/s]
#
# landmark.onnx:  73%|█████████████████▌      | 83.9M/115M [00:01<00:00, 67.8MB/s]
#
#
#
#
#
# warping_module.pth:  35%|██████▌            | 62.9M/182M [00:01<00:01, 62.6MB/s]
# motion_extractor.pth:  65%|███████████      | 73.4M/113M [00:01<00:00, 65.5MB/s]
#
#
#
#
# motion_extractor.pth: 100%|██████████████████| 113M/113M [00:01<00:00, 64.5MB/s]
#
#
# motion_extractor.pth: 100%|██████████████████| 113M/113M [00:01<00:00, 69.0MB/s]
# Download complete. Moving file to pretrained_weights/liveportrait/base_models/motion_extractor.pth
# Fetching 16 files:  38%|█████████▍               | 6/16 [00:01<00:03,  2.84it/s]
#
#
#
# warping_module.pth:  69%|█████████████▊      | 126M/182M [00:01<00:00, 69.7MB/s]
#
#
#
#
#
#
# spade_generator.pth:  52%|█████████▉         | 115M/222M [00:01<00:01, 65.8MB/s]
#
#
#
#
#
#
#
# xpose.pth:  14%|████                        | 62.9M/435M [00:00<00:05, 70.6MB/s]
#
# landmark.onnx:  82%|███████████████████▊    | 94.4M/115M [00:01<00:00, 68.0MB/s]
#
#
#
#
#
# warping_module.pth:  40%|███████▋           | 73.4M/182M [00:01<00:01, 66.5MB/s]
# motion_extractor.pth:  75%|████████████▋    | 83.9M/113M [00:01<00:00, 68.3MB/s]
#
#
# spade_generator.pth:  38%|██████▊           | 83.9M/222M [00:01<00:02, 67.4MB/s]
#
#
#
# warping_module.pth:  75%|██████████████▉     | 136M/182M [00:01<00:00, 71.8MB/s]
#
#
#
#
#
#
# spade_generator.pth:  57%|██████████▊        | 126M/222M [00:01<00:01, 69.5MB/s]
#
#
#
#
#
#
#
# xpose.pth:  17%|████▋                       | 73.4M/435M [00:01<00:04, 72.5MB/s]
#
# landmark.onnx:  91%|██████████████████████▊  | 105M/115M [00:01<00:00, 70.6MB/s]
#
#
#
#
#
# warping_module.pth:  46%|████████▋          | 83.9M/182M [00:01<00:01, 68.7MB/s]
# motion_extractor.pth:  84%|██████████████▎  | 94.4M/113M [00:01<00:00, 70.0MB/s]
#
#
# spade_generator.pth:  43%|███████▋          | 94.4M/222M [00:01<00:01, 71.0MB/s]
#
#
#
# warping_module.pth:  81%|████████████████    | 147M/182M [00:01<00:00, 73.2MB/s]
#
#
#
#
#
#
# spade_generator.pth:  61%|███████████▋       | 136M/222M [00:01<00:01, 73.0MB/s]
#
# landmark.onnx: 100%|█████████████████████████| 115M/115M [00:01<00:00, 74.0MB/s]
#
#
#
#
#
#
#
# landmark.onnx: 100%|█████████████████████████| 115M/115M [00:01<00:00, 68.9MB/s]
# Download complete. Moving file to pretrained_weights/liveportrait/landmark.onnx
#
#
#
#
#
#
# warping_module.pth:  52%|█████████▊         | 94.4M/182M [00:01<00:01, 70.1MB/s]
#
#
# spade_generator.pth:  47%|████████▉          | 105M/222M [00:01<00:01, 76.0MB/s]
# motion_extractor.pth:  93%|████████████████▊ | 105M/113M [00:01<00:00, 71.4MB/s]
#
#
#
# warping_module.pth:  86%|█████████████████▎  | 157M/182M [00:02<00:00, 79.4MB/s]
#
#
#
#
#
#
#
# xpose.pth:  22%|██████                      | 94.4M/435M [00:01<00:04, 79.8MB/s]
#
#
#
#
#
#
# spade_generator.pth:  66%|████████████▌      | 147M/222M [00:02<00:01, 74.1MB/s]
#
#
#
#
#
# warping_module.pth:  58%|███████████▌        | 105M/182M [00:01<00:00, 77.5MB/s]
#
#
# motion_extractor.pth: 100%|██████████████████| 113M/113M [00:01<00:00, 67.3MB/s]
# Download complete. Moving file to pretrained_weights/liveportrait_animals/base_models/motion_extractor.pth
#
#
#
#
#
#
#
#
# xpose.pth:  24%|██████▉                      | 105M/435M [00:01<00:03, 84.6MB/s]
#
#
#
# warping_module.pth:  98%|███████████████████▌| 178M/182M [00:02<00:00, 92.4MB/s]
#
#
#
#
#
#
# warping_module.pth: 100%|████████████████████| 182M/182M [00:02<00:00, 80.2MB/s]
# Download complete. Moving file to pretrained_weights/liveportrait/base_models/warping_module.pth
#
#
#
# spade_generator.pth:  61%|████████████▎       | 136M/222M [00:01<00:00, 101MB/s]
#
#
#
#
#
# warping_module.pth:  69%|█████████████▊      | 126M/182M [00:01<00:00, 92.9MB/s]
#
#
#
#
#
#
#
# xpose.pth:  29%|████████▋                     | 126M/435M [00:01<00:03, 102MB/s]
#
#
#
#
#
#
# spade_generator.pth:  85%|█████████████████   | 189M/222M [00:02<00:00, 109MB/s]
#
#
# spade_generator.pth:  71%|██████████████▏     | 157M/222M [00:01<00:00, 117MB/s]
#
#
#
#
#
# warping_module.pth:  81%|████████████████▉    | 147M/182M [00:01<00:00, 111MB/s]
#
#
#
#
#
#
#
# xpose.pth:  34%|██████████                    | 147M/435M [00:01<00:02, 122MB/s]
#
#
#
#
#
#
# spade_generator.pth:  95%|██████████████████▉ | 210M/222M [00:02<00:00, 127MB/s]
#
#
# spade_generator.pth:  80%|████████████████    | 178M/222M [00:02<00:00, 133MB/s]
#
#
#
#
#
# warping_module.pth:  92%|███████████████████▎ | 168M/182M [00:01<00:00, 126MB/s]
#
#
#
#
#
#
#
# spade_generator.pth: 100%|███████████████████| 222M/222M [00:02<00:00, 85.9MB/s]
# Download complete. Moving file to pretrained_weights/liveportrait/base_models/spade_generator.pth
# Fetching 16 files:  44%|██████████▉              | 7/16 [00:02<00:04,  2.06it/s]
#
#
# warping_module.pth: 100%|████████████████████| 182M/182M [00:02<00:00, 88.5MB/s]
# Download complete. Moving file to pretrained_weights/liveportrait_animals/base_models/warping_module.pth
#
#
#
#
#
#
#
#
# spade_generator.pth: 100%|███████████████████| 222M/222M [00:02<00:00, 98.5MB/s]
# Download complete. Moving file to pretrained_weights/liveportrait_animals/base_models/spade_generator.pth
# Fetching 16 files:  81%|███████████████████▌    | 13/16 [00:03<00:00,  5.51it/s]
#
#
#
#
#
#
#
# xpose.pth:  53%|███████████████▉              | 231M/435M [00:02<00:01, 189MB/s]
#
#
#
#
#
#
#
# xpose.pth:  60%|██████████████████            | 262M/435M [00:02<00:00, 208MB/s]
#
#
#
#
#
#
#
# xpose.pth:  67%|████████████████████▏         | 294M/435M [00:02<00:00, 226MB/s]
#
#
#
#
#
#
#
# xpose.pth:  75%|██████████████████████▍       | 325M/435M [00:02<00:00, 234MB/s]
#
#
#
#
#
#
#
# xpose.pth:  82%|████████████████████████▌     | 357M/435M [00:02<00:00, 250MB/s]
#
#
#
#
#
#
#
# xpose.pth:  89%|██████████████████████████▊   | 388M/435M [00:02<00:00, 258MB/s]
#
#
#
#
#
#
#
# xpose.pth: 100%|██████████████████████████████| 435M/435M [00:02<00:00, 152MB/s]
# Download complete. Moving file to pretrained_weights/liveportrait_animals/xpose.pth
# Fetching 16 files: 100%|████████████████████████| 16/16 [00:03<00:00,  4.09it/s]
# /kaggle/working/LivePortrait/pretrained_weights

# %% [markdown]
# ##  run below after reboot

# %%
# %cd /kaggle/working/LivePortrait
# !git checkout .
# !git pull
# !pip install -r requirements.txt
# Out:
# /kaggle/working/LivePortrait
# Updated 211 paths from the index
# Already up to date.
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.10/dist-packages (from -r requirements_base.txt (line 1)) (1.26.4)
# Collecting pyyaml==6.0.1 (from -r requirements_base.txt (line 2))
#   Downloading PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: opencv-python==4.10.0.84 in /usr/local/lib/python3.10/dist-packages (from -r requirements_base.txt (line 3)) (4.10.0.84)
# Requirement already satisfied: scipy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from -r requirements_base.txt (line 4)) (1.13.1)
# Collecting imageio==2.34.2 (from -r requirements_base.txt (line 5))
#   Downloading imageio-2.34.2-py3-none-any.whl.metadata (4.9 kB)
# Collecting lmdb==1.4.1 (from -r requirements_base.txt (line 6))
#   Downloading lmdb-1.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.2 kB)
# Collecting tqdm==4.66.4 (from -r requirements_base.txt (line 7))
#   Downloading tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.2 MB/s eta 0:00:00
# Collecting rich==13.7.1 (from -r requirements_base.txt (line 8))
#   Downloading rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Collecting ffmpeg-python==0.2.0 (from -r requirements_base.txt (line 9))
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting onnx==1.16.1 (from -r requirements_base.txt (line 10))
#   Downloading onnx-1.16.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: scikit-image==0.24.0 in /usr/local/lib/python3.10/dist-packages (from -r requirements_base.txt (line 11)) (0.24.0)
# Collecting albumentations==1.4.10 (from -r requirements_base.txt (line 12))
#   Downloading albumentations-1.4.10-py3-none-any.whl.metadata (38 kB)
# Collecting matplotlib==3.9.0 (from -r requirements_base.txt (line 13))
#   Downloading matplotlib-3.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: imageio-ffmpeg==0.5.1 in /usr/local/lib/python3.10/dist-packages (from -r requirements_base.txt (line 14)) (0.5.1)
# Collecting tyro==0.8.5 (from -r requirements_base.txt (line 15))
#   Downloading tyro-0.8.5-py3-none-any.whl.metadata (8.2 kB)
# Collecting gradio==5.1.0 (from -r requirements_base.txt (line 16))
#   Downloading gradio-5.1.0-py3-none-any.whl.metadata (15 kB)
# Collecting pykalman==0.9.7 (from -r requirements_base.txt (line 17))
#   Downloading pykalman-0.9.7-py2.py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: pillow>=10.2.0 in /usr/local/lib/python3.10/dist-packages (from -r requirements_base.txt (line 18)) (10.4.0)
# Collecting onnxruntime-gpu==1.18.0 (from -r requirements.txt (line 3))
#   Downloading onnxruntime_gpu-1.18.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (4.3 kB)
# Collecting transformers==4.38.0 (from -r requirements.txt (line 4))
#   Downloading transformers-4.38.0-py3-none-any.whl.metadata (131 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.1/131.1 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich==13.7.1->-r requirements_base.txt (line 8)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich==13.7.1->-r requirements_base.txt (line 8)) (2.18.0)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from ffmpeg-python==0.2.0->-r requirements_base.txt (line 9)) (1.0.0)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from onnx==1.16.1->-r requirements_base.txt (line 10)) (3.20.3)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.24.0->-r requirements_base.txt (line 11)) (3.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.24.0->-r requirements_base.txt (line 11)) (2024.8.30)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.24.0->-r requirements_base.txt (line 11)) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.24.0->-r requirements_base.txt (line 11)) (0.4)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.4.10->-r requirements_base.txt (line 12)) (4.12.2)
# Collecting scikit-learn>=1.3.2 (from albumentations==1.4.10->-r requirements_base.txt (line 12))
#   Downloading scikit_learn-1.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: pydantic>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.4.10->-r requirements_base.txt (line 12)) (2.9.2)
# Requirement already satisfied: albucore>=0.0.11 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.4.10->-r requirements_base.txt (line 12)) (0.0.16)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.4.10->-r requirements_base.txt (line 12)) (4.10.0.84)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.9.0->-r requirements_base.txt (line 13)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.9.0->-r requirements_base.txt (line 13)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.9.0->-r requirements_base.txt (line 13)) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.9.0->-r requirements_base.txt (line 13)) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.9.0->-r requirements_base.txt (line 13)) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.9.0->-r requirements_base.txt (line 13)) (2.8.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from imageio-ffmpeg==0.5.1->-r requirements_base.txt (line 14)) (71.0.4)
# Requirement already satisfied: docstring-parser>=0.16 in /usr/local/lib/python3.10/dist-packages (from tyro==0.8.5->-r requirements_base.txt (line 15)) (0.16)
# Collecting shtab>=1.5.6 (from tyro==0.8.5->-r requirements_base.txt (line 15))
#   Downloading shtab-1.7.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.10/dist-packages (from gradio==5.1.0->-r requirements_base.txt (line 16)) (22.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio==5.1.0->-r requirements_base.txt (line 16)) (3.7.1)
# Collecting fastapi<1.0 (from gradio==5.1.0->-r requirements_base.txt (line 16))
#   Downloading fastapi-0.115.6-py3-none-any.whl.metadata (27 kB)
# Collecting ffmpy (from gradio==5.1.0->-r requirements_base.txt (line 16))
#   Downloading ffmpy-0.5.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting gradio-client==1.4.0 (from gradio==5.1.0->-r requirements_base.txt (line 16))
#   Downloading gradio_client-1.4.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting httpx>=0.24.1 (from gradio==5.1.0->-r requirements_base.txt (line 16))
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting huggingface-hub>=0.25.1 (from gradio==5.1.0->-r requirements_base.txt (line 16))
#   Downloading huggingface_hub-0.27.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio==5.1.0->-r requirements_base.txt (line 16)) (3.1.4)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==5.1.0->-r requirements_base.txt (line 16)) (2.1.5)
# Collecting orjson~=3.0 (from gradio==5.1.0->-r requirements_base.txt (line 16))
#   Downloading orjson-3.10.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio==5.1.0->-r requirements_base.txt (line 16)) (2.1.4)
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (from gradio==5.1.0->-r requirements_base.txt (line 16)) (0.25.1)
# Collecting python-multipart>=0.0.9 (from gradio==5.1.0->-r requirements_base.txt (line 16))
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Collecting ruff>=0.2.2 (from gradio==5.1.0->-r requirements_base.txt (line 16))
#   Downloading ruff-0.8.4-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting semantic-version~=2.0 (from gradio==5.1.0->-r requirements_base.txt (line 16))
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting tomlkit==0.12.0 (from gradio==5.1.0->-r requirements_base.txt (line 16))
#   Downloading tomlkit-0.12.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.10/dist-packages (from gradio==5.1.0->-r requirements_base.txt (line 16)) (0.12.5)
# Collecting uvicorn>=0.14.0 (from gradio==5.1.0->-r requirements_base.txt (line 16))
#   Downloading uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting coloredlogs (from onnxruntime-gpu==1.18.0->-r requirements.txt (line 3))
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime-gpu==1.18.0->-r requirements.txt (line 3)) (24.3.25)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime-gpu==1.18.0->-r requirements.txt (line 3)) (1.13.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.38.0->-r requirements.txt (line 4)) (3.16.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.38.0->-r requirements.txt (line 4)) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.38.0->-r requirements.txt (line 4)) (2.32.3)
# Collecting tokenizers<0.19,>=0.14 (from transformers==4.38.0->-r requirements.txt (line 4))
#   Downloading tokenizers-0.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.38.0->-r requirements.txt (line 4)) (0.4.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio-client==1.4.0->gradio==5.1.0->-r requirements_base.txt (line 16)) (2024.6.1)
# Collecting websockets<13.0,>=10.0 (from gradio-client==1.4.0->gradio==5.1.0->-r requirements_base.txt (line 16))
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio==5.1.0->-r requirements_base.txt (line 16)) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio==5.1.0->-r requirements_base.txt (line 16)) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio==5.1.0->-r requirements_base.txt (line 16)) (1.2.2)
# Collecting starlette<0.42.0,>=0.40.0 (from fastapi<1.0->gradio==5.1.0->-r requirements_base.txt (line 16))
#   Downloading starlette-0.41.3-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio==5.1.0->-r requirements_base.txt (line 16)) (2024.8.30)
# Collecting httpcore==1.* (from httpx>=0.24.1->gradio==5.1.0->-r requirements_base.txt (line 16))
#   Downloading httpcore-1.0.7-py3-none-any.whl.metadata (21 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.24.1->gradio==5.1.0->-r requirements_base.txt (line 16))
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich==13.7.1->-r requirements_base.txt (line 8)) (0.1.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio==5.1.0->-r requirements_base.txt (line 16)) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio==5.1.0->-r requirements_base.txt (line 16)) (2024.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.7.0->albumentations==1.4.10->-r requirements_base.txt (line 12)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.7.0->albumentations==1.4.10->-r requirements_base.txt (line 12)) (2.23.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib==3.9.0->-r requirements_base.txt (line 13)) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.3.2->albumentations==1.4.10->-r requirements_base.txt (line 12)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.3.2->albumentations==1.4.10->-r requirements_base.txt (line 12)) (3.5.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio==5.1.0->-r requirements_base.txt (line 16)) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio==5.1.0->-r requirements_base.txt (line 16)) (1.5.4)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime-gpu==1.18.0->-r requirements.txt (line 3))
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.38.0->-r requirements.txt (line 4)) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.38.0->-r requirements.txt (line 4)) (2.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime-gpu==1.18.0->-r requirements.txt (line 3)) (1.3.0)
# Downloading PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (705 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.5/705.5 kB 24.0 MB/s eta 0:00:00
# Downloading imageio-2.34.2-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.5/313.5 kB 20.3 MB/s eta 0:00:00
# Downloading lmdb-1.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (299 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.2/299.2 kB 19.6 MB/s eta 0:00:00
# Downloading tqdm-4.66.4-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 6.4 MB/s eta 0:00:00
# Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.7/240.7 kB 16.2 MB/s eta 0:00:00
# Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Downloading onnx-1.16.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 91.1 MB/s eta 0:00:00:00:0100:01
# Downloading albumentations-1.4.10-py3-none-any.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.9/161.9 kB 10.5 MB/s eta 0:00:00
# Downloading matplotlib-3.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 108.3 MB/s eta 0:00:0000:0100:01
# Downloading tyro-0.8.5-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.4/103.4 kB 7.3 MB/s eta 0:00:00
# Downloading gradio-5.1.0-py3-none-any.whl (42.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 MB 43.4 MB/s eta 0:00:00:00:0100:01
# Downloading pykalman-0.9.7-py2.py3-none-any.whl (251 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.6/251.6 kB 15.9 MB/s eta 0:00:00
# Downloading onnxruntime_gpu-1.18.0-cp310-cp310-manylinux_2_28_x86_64.whl (199.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 MB 8.5 MB/s eta 0:00:000:00:0100:01
# Downloading transformers-4.38.0-py3-none-any.whl (8.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 111.7 MB/s eta 0:00:0000:0100:01
# Downloading gradio_client-1.4.0-py3-none-any.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.8/319.8 kB 21.2 MB/s eta 0:00:00
# Downloading tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Downloading fastapi-0.115.6-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 7.7 MB/s eta 0:00:00
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 5.6 MB/s eta 0:00:00
# Downloading httpcore-1.0.7-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 5.8 MB/s eta 0:00:00
# Downloading huggingface_hub-0.27.0-py3-none-any.whl (450 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 450.5/450.5 kB 25.7 MB/s eta 0:00:00
# Downloading orjson-3.10.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (131 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.3/131.3 kB 9.9 MB/s eta 0:00:00
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading ruff-0.8.4-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 116.2 MB/s eta 0:00:0000:010:01
# Downloading scikit_learn-1.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 105.5 MB/s eta 0:00:0000:010:01
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading shtab-1.7.1-py3-none-any.whl (14 kB)
# Downloading tokenizers-0.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 90.5 MB/s eta 0:00:00:00:01
# Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 4.3 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.9 MB/s eta 0:00:00
# Downloading ffmpy-0.5.0-py3-none-any.whl (6.0 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.2 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.9 MB/s eta 0:00:00
# Downloading starlette-0.41.3-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 5.9 MB/s eta 0:00:00
# Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 8.9 MB/s eta 0:00:00
# Installing collected packages: lmdb, websockets, tqdm, tomlkit, shtab, semantic-version, ruff, pyyaml, python-multipart, orjson, onnx, imageio, humanfriendly, h11, ffmpy, ffmpeg-python, uvicorn, starlette, scikit-learn, rich, pykalman, matplotlib, huggingface-hub, httpcore, coloredlogs, tyro, tokenizers, onnxruntime-gpu, httpx, fastapi, albumentations, transformers, gradio-client, gradio
#   Attempting uninstall: websockets
#     Found existing installation: websockets 14.1
#     Uninstalling websockets-14.1:
#       Successfully uninstalled websockets-14.1
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.5
#     Uninstalling tqdm-4.66.5:
#       Successfully uninstalled tqdm-4.66.5
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0.2
#     Uninstalling PyYAML-6.0.2:
#       Successfully uninstalled PyYAML-6.0.2
#   Attempting uninstall: onnx
#     Found existing installation: onnx 1.17.0
#     Uninstalling onnx-1.17.0:
#       Successfully uninstalled onnx-1.17.0
#   Attempting uninstall: imageio
#     Found existing installation: imageio 2.35.1
#     Uninstalling imageio-2.35.1:
#       Successfully uninstalled imageio-2.35.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: rich
#     Found existing installation: rich 13.8.1
#     Uninstalling rich-13.8.1:
#       Successfully uninstalled rich-13.8.1
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.24.7
#     Uninstalling huggingface-hub-0.24.7:
#       Successfully uninstalled huggingface-hub-0.24.7
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.19.1
#     Uninstalling tokenizers-0.19.1:
#       Successfully uninstalled tokenizers-0.19.1
#   Attempting uninstall: albumentations
#     Found existing installation: albumentations 1.4.15
#     Uninstalling albumentations-1.4.15:
#       Successfully uninstalled albumentations-1.4.15
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.44.2
#     Uninstalling transformers-4.44.2:
#       Successfully uninstalled transformers-4.44.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 18.1.0 which is incompatible.
# distributed 2024.8.0 requires dask==2024.8.0, but you have dask 2024.12.1 which is incompatible.
# google-genai 0.3.0 requires websockets<15.0dev,>=13.0, but you have websockets 12.0 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 18.1.0 which is incompatible.
# Successfully installed albumentations-1.4.10 coloredlogs-15.0.1 fastapi-0.115.6 ffmpeg-python-0.2.0 ffmpy-0.5.0 gradio-5.1.0 gradio-client-1.4.0 h11-0.14.0 httpcore-1.0.7 httpx-0.28.1 huggingface-hub-0.27.0 humanfriendly-10.0 imageio-2.34.2 lmdb-1.4.1 matplotlib-3.9.0 onnx-1.16.1 onnxruntime-gpu-1.18.0 orjson-3.10.12 pykalman-0.9.7 python-multipart-0.0.20 pyyaml-6.0.1 rich-13.7.1 ruff-0.8.4 scikit-learn-1.6.0 semantic-version-2.10.0 shtab-1.7.1 starlette-0.41.3 tokenizers-0.15.2 tomlkit-0.12.0 tqdm-4.66.4 transformers-4.38.0 tyro-0.8.5 uvicorn-0.34.0 websockets-12.0

# %%
# %cd /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops
# !python setup.py build install
# %cd ../../../../../../../
# Out:
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:414: UserWarning: The detected CUDA version (12.2) has a minor version mismatch with the version that was used to compile PyTorch (12.1). Most likely this shouldn't be a problem.
#   warnings.warn(CUDA_MISMATCH_WARN.format(cuda_str_version, torch.version.cuda))
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:424: UserWarning: There are no x86_64-linux-gnu-g++ version bounds defined for CUDA version 12.2
#   warnings.warn(f'There are no {compiler_name} version bounds defined for CUDA version {cuda_str_version}')
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:1965: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# Emitting ninja build file /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/build/temp.linux-x86_64-cpython-310/build.ninja...
# Compiling objects...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# [1/3] c++ -MMD -MF /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/build/temp.linux-x86_64-cpython-310/kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cpu/ms_deform_attn_cpu.o.d -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DWITH_CUDA -I/kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src -I/usr/local/lib/python3.10/dist-packages/torch/include -I/usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.10/dist-packages/torch/include/TH -I/usr/local/lib/python3.10/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.10 -c -c /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cpu/ms_deform_attn_cpu.cpp -o /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/build/temp.linux-x86_64-cpython-310/kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cpu/ms_deform_attn_cpu.o -DTORCH_API_INCLUDE_EXTENSION_H '-DPYBIND11_COMPILER_TYPE="_gcc"' '-DPYBIND11_STDLIB="_libstdcpp"' '-DPYBIND11_BUILD_ABI="_cxxabi1011"' -DTORCH_EXTENSION_NAME=MultiScaleDeformableAttention -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++17
# [2/3] /usr/local/cuda/bin/nvcc --generate-dependencies-with-compile --dependency-output /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/build/temp.linux-x86_64-cpython-310/kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.o.d -DWITH_CUDA -I/kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src -I/usr/local/lib/python3.10/dist-packages/torch/include -I/usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.10/dist-packages/torch/include/TH -I/usr/local/lib/python3.10/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.10 -c -c /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu -o /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/build/temp.linux-x86_64-cpython-310/kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options ''"'"'-fPIC'"'"'' -DCUDA_HAS_FP16=1 -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ -DTORCH_API_INCLUDE_EXTENSION_H '-DPYBIND11_COMPILER_TYPE="_gcc"' '-DPYBIND11_STDLIB="_libstdcpp"' '-DPYBIND11_BUILD_ABI="_cxxabi1011"' -DTORCH_EXTENSION_NAME=MultiScaleDeformableAttention -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_60,code=compute_60 -gencode=arch=compute_60,code=sm_60 -std=c++17
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_im2col_cuda.cuh(261): warning #177-D: variable "q_col" was declared but never referenced
#       const int q_col = _temp % num_query;
#                 ^
#           detected during instantiation of "void ms_deformable_im2col_cuda(cudaStream_t, const scalar_t *, const int64_t *, const int64_t *, const scalar_t *, const scalar_t *, int, int, int, int, int, int, int, scalar_t *) [with scalar_t=double]" at line 64 of /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu
#
# Remark: The warnings can be suppressed with "-diag-suppress <warning-number>"
#
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_im2col_cuda.cuh(762): warning #177-D: variable "q_col" was declared but never referenced
#       const int q_col = _temp % num_query;
#                 ^
#           detected during instantiation of "void ms_deformable_col2im_cuda(cudaStream_t, const scalar_t *, const scalar_t *, const int64_t *, const int64_t *, const scalar_t *, const scalar_t *, int, int, int, int, int, int, int, scalar_t *, scalar_t *, scalar_t *) [with scalar_t=double]" at line 134 of /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu
#
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_im2col_cuda.cuh(872): warning #177-D: variable "q_col" was declared but never referenced
#       const int q_col = _temp % num_query;
#                 ^
#           detected during instantiation of "void ms_deformable_col2im_cuda(cudaStream_t, const scalar_t *, const scalar_t *, const int64_t *, const int64_t *, const scalar_t *, const scalar_t *, int, int, int, int, int, int, int, scalar_t *, scalar_t *, scalar_t *) [with scalar_t=double]" at line 134 of /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu
#
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_im2col_cuda.cuh(331): warning #177-D: variable "q_col" was declared but never referenced
#       const int q_col = _temp % num_query;
#                 ^
#           detected during instantiation of "void ms_deformable_col2im_cuda(cudaStream_t, const scalar_t *, const scalar_t *, const int64_t *, const int64_t *, const scalar_t *, const scalar_t *, int, int, int, int, int, int, int, scalar_t *, scalar_t *, scalar_t *) [with scalar_t=double]" at line 134 of /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu
#
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_im2col_cuda.cuh(436): warning #177-D: variable "q_col" was declared but never referenced
#       const int q_col = _temp % num_query;
#                 ^
#           detected during instantiation of "void ms_deformable_col2im_cuda(cudaStream_t, const scalar_t *, const scalar_t *, const int64_t *, const int64_t *, const scalar_t *, const scalar_t *, int, int, int, int, int, int, int, scalar_t *, scalar_t *, scalar_t *) [with scalar_t=double]" at line 134 of /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu
#
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_im2col_cuda.cuh(544): warning #177-D: variable "q_col" was declared but never referenced
#       const int q_col = _temp % num_query;
#                 ^
#           detected during instantiation of "void ms_deformable_col2im_cuda(cudaStream_t, const scalar_t *, const scalar_t *, const int64_t *, const int64_t *, const scalar_t *, const scalar_t *, int, int, int, int, int, int, int, scalar_t *, scalar_t *, scalar_t *) [with scalar_t=double]" at line 134 of /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu
#
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_im2col_cuda.cuh(649): warning #177-D: variable "q_col" was declared but never referenced
#       const int q_col = _temp % num_query;
#                 ^
#           detected during instantiation of "void ms_deformable_col2im_cuda(cudaStream_t, const scalar_t *, const scalar_t *, const int64_t *, const int64_t *, const scalar_t *, const scalar_t *, int, int, int, int, int, int, int, scalar_t *, scalar_t *, scalar_t *) [with scalar_t=double]" at line 134 of /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu
#
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu: In function ‘at::Tensor ms_deform_attn_cuda_forward(const at::Tensor&, const at::Tensor&, const at::Tensor&, const at::Tensor&, const at::Tensor&, int)’:
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu:34:61: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#    34 |     AT_ASSERTM(value.type().is_cuda(), "value must be a CUDA tensor");
#       |                                                   ~~~~~~~~~~^~
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:225:1: note: declared here
#   225 |   DeprecatedTypeProperties & type() const {
#       | ^ ~~
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu:35:70: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#    35 |     AT_ASSERTM(spatial_shapes.type().is_cuda(), "spatial_shapes must be a CUDA tensor");
#       |                                                   ~~~~~~~~~~~~~~~~~~~^~
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:225:1: note: declared here
#   225 |   DeprecatedTypeProperties & type() const {
#       | ^ ~~
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu:36:73: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#    36 |     AT_ASSERTM(level_start_index.type().is_cuda(), "level_start_index must be a CUDA tensor");
#       |                                                   ~~~~~~~~~~~~~~~~~~~~~~^~
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:225:1: note: declared here
#   225 |   DeprecatedTypeProperties & type() const {
#       | ^ ~~
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu:37:68: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#    37 |     AT_ASSERTM(sampling_loc.type().is_cuda(), "sampling_loc must be a CUDA tensor");
#       |                                                   ~~~~~~~~~~~~~~~~~^~
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:225:1: note: declared here
#   225 |   DeprecatedTypeProperties & type() const {
#       | ^ ~~
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu:38:67: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#    38 |     AT_ASSERTM(attn_weight.type().is_cuda(), "attn_weight must be a CUDA tensor");
#       |                                                   ~~~~~~~~~~~~~~~~^~
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:225:1: note: declared here
#   225 |   DeprecatedTypeProperties & type() const {
#       | ^ ~~
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu: In lambda function:
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu:64:42: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#    64 |         AT_DISPATCH_FLOATING_TYPES(value.type(), "ms_deform_attn_forward_cuda", ([&] {
#       |                              ~~~~~~~~~~~~^~
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:225:1: note: declared here
#   225 |   DeprecatedTypeProperties & type() const {
#       | ^ ~~
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu:64:163: warning: ‘c10::ScalarType detail::scalar_type(const at::DeprecatedTypeProperties&)’ is deprecated: passing at::DeprecatedTypeProperties to an AT_DISPATCH macro is deprecated, pass an at::ScalarType instead [-Wdeprecated-declarations]
#    64 |         AT_DISPATCH_FLOATING_TYPES(value.type(), "ms_deform_attn_forward_cuda", ([&] {
#       |                                                                                                                                                                   ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/Dispatch.h:109:1: note: declared here
#   109 | inline at::ScalarType scalar_type(const at::DeprecatedTypeProperties& t) {
#       | ^~~~~~~~~~~
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu: In lambda function:
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu:64:1087: warning: ‘T* at::Tensor::data() const [with T = double]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    64 |         AT_DISPATCH_FLOATING_TYPES(value.type(), "ms_deform_attn_forward_cuda", ([&] {
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu:64:1173: warning: ‘T* at::Tensor::data() const [with T = long int]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    64 |         AT_DISPATCH_FLOATING_TYPES(value.type(), "ms_deform_attn_forward_cuda", ([&] {
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu:64:1216: warning: ‘T* at::Tensor::data() const [with T = long int]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    64 |         AT_DISPATCH_FLOATING_TYPES(value.type(), "ms_deform_attn_forward_cuda", ([&] {
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu:64:1249: warning: ‘T* at::Tensor::data() const [with T = double]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    64 |         AT_DISPATCH_FLOATING_TYPES(value.type(), "ms_deform_attn_forward_cuda", ([&] {
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu:64:1332: warning: ‘T* at::Tensor::data() const [with T = double]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    64 |         AT_DISPATCH_FLOATING_TYPES(value.type(), "ms_deform_attn_forward_cuda", ([&] {
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu:64:1490: warning: ‘T* at::Tensor::data() const [with T = double]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    64 |         AT_DISPATCH_FLOATING_TYPES(value.type(), "ms_deform_attn_forward_cuda", ([&] {
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu: In lambda function:
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu:64:2394: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    64 |         AT_DISPATCH_FLOATING_TYPES(value.type(), "ms_deform_attn_forward_cuda", ([&] {
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu:64:2480: warning: ‘T* at::Tensor::data() const [with T = long int]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    64 |         AT_DISPATCH_FLOATING_TYPES(value.type(), "ms_deform_attn_forward_cuda", ([&] {
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu:64:2523: warning: ‘T* at::Tensor::data() const [with T = long int]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    64 |         AT_DISPATCH_FLOATING_TYPES(value.type(), "ms_deform_attn_forward_cuda", ([&] {
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu:64:2555: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    64 |         AT_DISPATCH_FLOATING_TYPES(value.type(), "ms_deform_attn_forward_cuda", ([&] {
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu:64:2637: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    64 |         AT_DISPATCH_FLOATING_TYPES(value.type(), "ms_deform_attn_forward_cuda", ([&] {
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu:64:2794: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    64 |         AT_DISPATCH_FLOATING_TYPES(value.type(), "ms_deform_attn_forward_cuda", ([&] {
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu: In function ‘std::vector<at::Tensor> ms_deform_attn_cuda_backward(const at::Tensor&, const at::Tensor&, const at::Tensor&, const at::Tensor&, const at::Tensor&, const at::Tensor&, int)’:
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu:100:61: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#   100 |     AT_ASSERTM(value.type().is_cuda(), "value must be a CUDA tensor");
#       |                                                   ~~~~~~~~~~^~
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:225:1: note: declared here
#   225 |   DeprecatedTypeProperties & type() const {
#       | ^ ~~
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu:101:70: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#   101 |     AT_ASSERTM(spatial_shapes.type().is_cuda(), "spatial_shapes must be a CUDA tensor");
#       |                                                   ~~~~~~~~~~~~~~~~~~~^~
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:225:1: note: declared here
#   225 |   DeprecatedTypeProperties & type() const {
#       | ^ ~~
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu:102:73: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
# ...
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu:134:3177: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   134 |         AT_DISPATCH_FLOATING_TYPES(value.type(), "ms_deform_attn_backward_cuda", ([&] {
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cuda/ms_deform_attn_cuda.cu:134:3264: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   134 |         AT_DISPATCH_FLOATING_TYPES(value.type(), "ms_deform_attn_backward_cuda", ([&] {
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# [3/3] c++ -MMD -MF /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/build/temp.linux-x86_64-cpython-310/kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/vision.o.d -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DWITH_CUDA -I/kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src -I/usr/local/lib/python3.10/dist-packages/torch/include -I/usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.10/dist-packages/torch/include/TH -I/usr/local/lib/python3.10/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.10 -c -c /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/vision.cpp -o /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/build/temp.linux-x86_64-cpython-310/kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/vision.o -DTORCH_API_INCLUDE_EXTENSION_H '-DPYBIND11_COMPILER_TYPE="_gcc"' '-DPYBIND11_STDLIB="_libstdcpp"' '-DPYBIND11_BUILD_ABI="_cxxabi1011"' -DTORCH_EXTENSION_NAME=MultiScaleDeformableAttention -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++17
# In file included from /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/vision.cpp:11:
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/ms_deform_attn.h: In function ‘at::Tensor ms_deform_attn_forward(const at::Tensor&, const at::Tensor&, const at::Tensor&, const at::Tensor&, const at::Tensor&, int)’:
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/ms_deform_attn.h:29:19: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#    29 |     if (value.type().is_cuda())
#       |         ~~~~~~~~~~^~
# In file included from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/function_hook.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/cpp_hook.h:2,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/variable.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/autograd.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/autograd.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/all.h:7,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/extension.h:5,
#                  from /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cpu/ms_deform_attn_cpu.h:12,
#                  from /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/ms_deform_attn.h:13,
#                  from /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/vision.cpp:11:
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:225:30: note: declared here
#   225 |   DeprecatedTypeProperties & type() const {
#       |                              ^~~~
# In file included from /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/vision.cpp:11:
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/ms_deform_attn.h: In function ‘std::vector<at::Tensor> ms_deform_attn_backward(const at::Tensor&, const at::Tensor&, const at::Tensor&, const at::Tensor&, const at::Tensor&, const at::Tensor&, int)’:
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/ms_deform_attn.h:51:19: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#    51 |     if (value.type().is_cuda())
#       |         ~~~~~~~~~~^~
# In file included from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/function_hook.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/cpp_hook.h:2,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/variable.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/autograd.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/autograd.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/all.h:7,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/extension.h:5,
#                  from /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/cpu/ms_deform_attn_cpu.h:12,
#                  from /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/ms_deform_attn.h:13,
#                  from /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/ops/src/vision.cpp:11:
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:225:30: note: declared here
#   225 |   DeprecatedTypeProperties & type() const {
#       |                              ^~~~
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /kaggle/working/LivePortrait

# %%
# start webui 
# %cd /kaggle/working/LivePortrait
# !npm install -g localtunnel
# !pip install --upgrade  gradio
# Out:
# /kaggle/working/LivePortrait
# m##################) ⠇ reify:yargs: http fetch GET 200 https://registry.npmjs.oistry.
# added 22 packages, and audited 23 packages in 2s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# 1 moderate severity vulnerability
#
# To address all issues (including breaking changes), run:
#   npm audit fix --force
#
# Run `npm audit` for details.
# npm notice
# npm notice New major version of npm available! 8.19.4 -> 11.0.0
# npm notice Changelog: https://github.com/npm/cli/releases/tag/v11.0.0
# npm notice Run npm install -g npm@11.0.0 to update!
# npm notice

# %%
# %cd /kaggle/working/LivePortrait
import subprocess
import urllib.request
# print("The password/enpoint ip for localtunnel is:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
# subprocess.Popen(["lt", "--port", "8188"])

# !python app.py --server_port=8188  --flag_do_torch_compile  --share#   humans mode
# !python app_animals.py  --server_port=8188  --flag_do_torch_compile --share #--no-share # animals mode
# Out:
# /kaggle/working/LivePortrait
# /kaggle/working/LivePortrait/src/utils/helper.py:170: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(ckpt_path, map_location=lambda storage, loc: storage))
# [07:18:36] Load appearance_feature_extractor from                       ]8;id=225818;file:///kaggle/working/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=348596;file:///kaggle/working/LivePortrait/src/live_portrait_wrapper.py#361\361]8;;\
#            /kaggle/working/LivePortrait/pretrained_weights/liveportrait
#            _animals/base_models/appearance_feature_extractor.pth done.
#            Load motion_extractor from                                   ]8;id=66531;file:///kaggle/working/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=440387;file:///kaggle/working/LivePortrait/src/live_portrait_wrapper.py#364\364]8;;\
#            /kaggle/working/LivePortrait/pretrained_weights/liveportrait
#            _animals/base_models/motion_extractor.pth done.
# [07:18:37] Load warping_module from                                     ]8;id=338674;file:///kaggle/working/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=383494;file:///kaggle/working/LivePortrait/src/live_portrait_wrapper.py#367\367]8;;\
#            /kaggle/working/LivePortrait/pretrained_weights/liveportrait
#            _animals/base_models/warping_module.pth done.
#            Load spade_generator from                                    ]8;id=979804;file:///kaggle/working/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=511313;file:///kaggle/working/LivePortrait/src/live_portrait_wrapper.py#370\370]8;;\
#            /kaggle/working/LivePortrait/pretrained_weights/liveportrait
#            _animals/base_models/spade_generator.pth done.
# /kaggle/working/LivePortrait/src/utils/helper.py:145: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(ckpt_path, map_location=lambda storage, loc: storage)
#            Load stitching_retargeting_module from                       ]8;id=887406;file:///kaggle/working/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=605923;file:///kaggle/working/LivePortrait/src/live_portrait_wrapper.py#374\374]8;;\
#            /kaggle/working/LivePortrait/pretrained_weights/liveportrait
#            /retargeting_models/stitching_retargeting_module.pth done.
# 2024-12-26 07:18:39.692902907 [E:onnxruntime:Default, provider_bridge_ort.cc:1744 TryGetProviderInfo_CUDA] /onnxruntime_src/onnxruntime/core/session/provider_bridge_ort.cc:1426 onnxruntime::Provider& onnxruntime::ProviderLibrary::Get() [ONNXRuntimeError] : 1 : FAIL : Failed to load library libonnxruntime_providers_cuda.so with error: libcublasLt.so.11: cannot open shared object file: No such file or directory
#
# 2024-12-26 07:18:39.720336232 [E:onnxruntime:Default, provider_bridge_ort.cc:1744 TryGetProviderInfo_CUDA] /onnxruntime_src/onnxruntime/core/session/provider_bridge_ort.cc:1426 onnxruntime::Provider& onnxruntime::ProviderLibrary::Get() [ONNXRuntimeError] : 1 : FAIL : Failed to load library libonnxruntime_providers_cuda.so with error: libcublasLt.so.11: cannot open shared object file: No such file or directory
#
# [07:18:39] FaceAnalysisDIY warmup time: 0.195s                               ]8;id=457218;file:///kaggle/working/LivePortrait/src/utils/face_analysis_diy.py\face_analysis_diy.py]8;;\:]8;id=985692;file:///kaggle/working/LivePortrait/src/utils/face_analysis_diy.py#79\79]8;;\
# 2024-12-26 07:18:40.085401135 [E:onnxruntime:Default, provider_bridge_ort.cc:1744 TryGetProviderInfo_CUDA] /onnxruntime_src/onnxruntime/core/session/provider_bridge_ort.cc:1426 onnxruntime::Provider& onnxruntime::ProviderLibrary::Get() [ONNXRuntimeError] : 1 : FAIL : Failed to load library libonnxruntime_providers_cuda.so with error: libcublasLt.so.11: cannot open shared object file: No such file or directory
#
# [07:18:40] LandmarkRunner warmup time: 0.100s                            ]8;id=545731;file:///kaggle/working/LivePortrait/src/utils/human_landmark_runner.py\human_landmark_runner.py]8;;\:]8;id=249933;file:///kaggle/working/LivePortrait/src/utils/human_landmark_runner.py#95\95]8;;\
# /kaggle/working/LivePortrait/src/utils/animal_landmark_runner.py:46: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(model_checkpoint_path, map_location=lambda storage, loc: storage)
# Loaded cached embeddings from file.
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/deformable_transformer.py:1052: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# [07:18:43] XPoseRunner warmup time: 1.409s                             ]8;id=160914;file:///kaggle/working/LivePortrait/src/utils/animal_landmark_runner.py\animal_landmark_runner.py]8;;\:]8;id=833265;file:///kaggle/working/LivePortrait/src/utils/animal_landmark_runner.py#138\138]8;;\
# * Running on local URL:  http://127.0.0.1:8188
# * Running on public URL: https://b378cad0ce54b89959.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# [07:36:17] Load source image from                                ]8;id=960546;file:///kaggle/working/LivePortrait/src/live_portrait_pipeline_animal.py\live_portrait_pipeline_animal.py]8;;\:]8;id=410495;file:///kaggle/working/LivePortrait/src/live_portrait_pipeline_animal.py#79\79]8;;\
#            /tmp/gradio/92c1e748701e20a5e0620347afd380dd3342784df
#            d4817da657e2d3c3ee3405b/s25.jpg
#            Load driving video from:                             ]8;id=58984;file:///kaggle/working/LivePortrait/src/live_portrait_pipeline_animal.py\live_portrait_pipeline_animal.py]8;;\:]8;id=35348;file:///kaggle/working/LivePortrait/src/live_portrait_pipeline_animal.py#104\104]8;;\
#            /tmp/gradio/b84576a1d6f5e76a7edc01282f45250329449153
#            acdffeab62834b394fa23254/v3-web-prime.douyinvod.mp4,
#             FPS is 30
# [07:36:19] Start making driving motion template...              ]8;id=316494;file:///kaggle/working/LivePortrait/src/live_portrait_pipeline_animal.py\live_portrait_pipeline_animal.py]8;;\:]8;id=240828;file:///kaggle/working/LivePortrait/src/live_portrait_pipeline_animal.py#110\110]8;;\
# Making driving motion templates... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:0900:0100:01
# [07:36:30] Dump motion template to                              ]8;id=678451;file:///kaggle/working/LivePortrait/src/live_portrait_pipeline_animal.py\live_portrait_pipeline_animal.py]8;;\:]8;id=384423;file:///kaggle/working/LivePortrait/src/live_portrait_pipeline_animal.py#128\128]8;;\
#            /tmp/gradio/b84576a1d6f5e76a7edc01282f45250329449153
#            acdffeab62834b394fa23254/v3-web-prime.douyinvod.pkl
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /kaggle/working/LivePortrait/src/utils/dependencies/XPose/models/UniPose/deformable_transformer.py:1052: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# 🚀Animating... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--W1226 07:36:35.549000 135376723240512 torch/_inductor/utils.py:977] [0/0] Not enough SMs to use max_autotune_gemm mode
# 🚀Animating... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009] WON'T CONVERT forward /kaggle/working/LivePortrait/src/modules/warping_network.py line 49
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009] due to:
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009] Traceback (most recent call last):
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 948, in __call__
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     result = self._inner_convert(
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 472, in __call__
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return _compile(
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_utils_internal.py", line 84, in wrapper_function
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return StrobelightCompileTimeProfiler.profile_compile_time(
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_strobelight/compile_time_profiler.py", line 129, in profile_compile_time
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwargs)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.10/contextlib.py", line 79, in inner
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 817, in _compile
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 636, in compile_inner
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     out_code = transform_code_object(code, transform)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/bytecode_transformation.py", line 1185, in transform_code_object
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     transformations(instructions, code_options)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 178, in _fn
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return fn(*args, **kwargs)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 582, in transform
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     tracer.run()
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 2451, in run
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     super().run()
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 893, in run
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     while self.step():
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 805, in step
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     self.dispatch_table[inst.opcode](self, inst)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 2642, in RETURN_VALUE
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     self._return(inst)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 2627, in _return
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     self.output.compile_subgraph(
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1123, in compile_subgraph
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     self.compile_and_call_fx_graph(tx, pass2.graph_output_vars(), root)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.10/contextlib.py", line 79, in inner
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1318, in compile_and_call_fx_graph
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     compiled_fn = self.call_user_compiler(gm)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1409, in call_user_compiler
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1390, in call_user_compiler
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/repro/after_dynamo.py", line 129, in __call__
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     compiled_gm = compiler_fn(gm, example_inputs)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/__init__.py", line 1951, in __call__
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return compile_fx(model_, inputs_, config_patches=self.config)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.10/contextlib.py", line 79, in inner
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 1261, in compile_fx
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return compile_fx(
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.10/contextlib.py", line 79, in inner
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 1505, in compile_fx
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return aot_autograd(
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/backends/common.py", line 69, in __call__
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/aot_autograd.py", line 954, in aot_module_simplified
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     compiled_fn, _ = create_aot_dispatcher_function(
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/aot_autograd.py", line 687, in create_aot_dispatcher_function
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     compiled_fn, fw_metadata = compiler_fn(
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/_aot_autograd/jit_compile_runtime_wrappers.py", line 168, in aot_dispatch_base
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     compiled_fw = compiler(fw_module, updated_flat_args)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 1410, in fw_compiler_base
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return inner_compile(
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.10/contextlib.py", line 79, in inner
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/repro/after_aot.py", line 84, in debug_wrapper
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/debug.py", line 304, in inner
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return fn(*args, **kwargs)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.10/contextlib.py", line 79, in inner
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.10/contextlib.py", line 79, in inner
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 527, in compile_fx_inner
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     compiled_graph = fx_codegen_and_compile(
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.10/contextlib.py", line 79, in inner
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 831, in fx_codegen_and_compile
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     compiled_fn = graph.compile_to_fn()
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/graph.py", line 1751, in compile_to_fn
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return self.compile_to_module().call
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/graph.py", line 1680, in compile_to_module
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/graph.py", line 1636, in codegen
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     self.scheduler = Scheduler(self.buffers)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 1364, in __init__
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 1364, in <listcomp>
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 1462, in create_scheduler_node
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return SchedulerNode(self, node)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 731, in __init__
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     self._compute_attrs()
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 742, in _compute_attrs
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     group_fn = self.scheduler.get_backend(self.node.get_device()).group_fn
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 2663, in get_backend
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     self.backends[device] = self.create_backend(device)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 2651, in create_backend
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     raise RuntimeError(
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009] RuntimeError: Found Tesla P100-PCIE-16GB which is too old to be supported by the triton GPU compiler, which is used as the backend. Triton only supports devices of CUDA Capability >= 7.0, but your device is of CUDA capability 6.0
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009] Traceback (most recent call last):
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 948, in __call__
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     result = self._inner_convert(
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 472, in __call__
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return _compile(
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_utils_internal.py", line 84, in wrapper_function
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return StrobelightCompileTimeProfiler.profile_compile_time(
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_strobelight/compile_time_profiler.py", line 129, in profile_compile_time
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwargs)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.10/contextlib.py", line 79, in inner
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 817, in _compile
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 636, in compile_inner
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     out_code = transform_code_object(code, transform)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/bytecode_transformation.py", line 1185, in transform_code_object
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     transformations(instructions, code_options)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 178, in _fn
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return fn(*args, **kwargs)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 582, in transform
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     tracer.run()
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 2451, in run
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     super().run()
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 893, in run
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     while self.step():
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 805, in step
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     self.dispatch_table[inst.opcode](self, inst)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 2642, in RETURN_VALUE
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     self._return(inst)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 2627, in _return
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     self.output.compile_subgraph(
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1123, in compile_subgraph
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     self.compile_and_call_fx_graph(tx, pass2.graph_output_vars(), root)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.10/contextlib.py", line 79, in inner
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1318, in compile_and_call_fx_graph
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     compiled_fn = self.call_user_compiler(gm)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1409, in call_user_compiler
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1390, in call_user_compiler
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/repro/after_dynamo.py", line 129, in __call__
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     compiled_gm = compiler_fn(gm, example_inputs)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/__init__.py", line 1951, in __call__
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return compile_fx(model_, inputs_, config_patches=self.config)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.10/contextlib.py", line 79, in inner
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 1261, in compile_fx
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return compile_fx(
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.10/contextlib.py", line 79, in inner
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 1505, in compile_fx
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return aot_autograd(
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/backends/common.py", line 69, in __call__
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/aot_autograd.py", line 954, in aot_module_simplified
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     compiled_fn, _ = create_aot_dispatcher_function(
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/aot_autograd.py", line 687, in create_aot_dispatcher_function
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     compiled_fn, fw_metadata = compiler_fn(
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/_aot_autograd/jit_compile_runtime_wrappers.py", line 168, in aot_dispatch_base
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     compiled_fw = compiler(fw_module, updated_flat_args)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 1410, in fw_compiler_base
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return inner_compile(
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.10/contextlib.py", line 79, in inner
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/repro/after_aot.py", line 84, in debug_wrapper
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/debug.py", line 304, in inner
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return fn(*args, **kwargs)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.10/contextlib.py", line 79, in inner
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.10/contextlib.py", line 79, in inner
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 527, in compile_fx_inner
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     compiled_graph = fx_codegen_and_compile(
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.10/contextlib.py", line 79, in inner
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 831, in fx_codegen_and_compile
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     compiled_fn = graph.compile_to_fn()
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/graph.py", line 1751, in compile_to_fn
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return self.compile_to_module().call
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/graph.py", line 1680, in compile_to_module
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/graph.py", line 1636, in codegen
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     self.scheduler = Scheduler(self.buffers)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 1364, in __init__
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 1364, in <listcomp>
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 1462, in create_scheduler_node
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return SchedulerNode(self, node)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 731, in __init__
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     self._compute_attrs()
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 742, in _compute_attrs
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     group_fn = self.scheduler.get_backend(self.node.get_device()).group_fn
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 2663, in get_backend
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     self.backends[device] = self.create_backend(device)
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 2651, in create_backend
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]     raise RuntimeError(
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009] RuntimeError: Found Tesla P100-PCIE-16GB which is too old to be supported by the triton GPU compiler, which is used as the backend. Triton only supports devices of CUDA Capability >= 7.0, but your device is of CUDA capability 6.0
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W1226 07:36:36.497000 135376723240512 torch/_dynamo/convert_frame.py:1009]
# 🚀Animating... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--W1226 07:36:39.904000 135376723240512 torch/_dynamo/convert_frame.py:1009] WON'T CONVERT forward /kaggle/working/LivePortrait/src/modules/dense_motion.py line 67
# W1226 07:36:39.904000 135376723240512 torch/_dynamo/convert_frame.py:1009] due to:
# W1226 07:36:39.904000 135376723240512 torch/_dynamo/convert_frame.py:1009] Traceback (most recent call last):
# W1226 07:36:39.904000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 948, in __call__
# W1226 07:36:39.904000 135376723240512 torch/_dynamo/convert_frame.py:1009]     result = self._inner_convert(
# W1226 07:36:39.904000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 472, in __call__
# W1226 07:36:39.904000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return _compile(
# W1226 07:36:39.904000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_utils_internal.py", line 84, in wrapper_function
# W1226 07:36:39.904000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return StrobelightCompileTimeProfiler.profile_compile_time(
# W1226 07:36:39.904000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_strobelight/compile_time_profiler.py", line 129, in profile_compile_time
# W1226 07:36:39.904000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwargs)
# W1226 07:36:39.904000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.10/contextlib.py", line 79, in inner
# ...
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.10/contextlib.py", line 79, in inner
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 817, in _compile
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 636, in compile_inner
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     out_code = transform_code_object(code, transform)
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/bytecode_transformation.py", line 1185, in transform_code_object
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     transformations(instructions, code_options)
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 178, in _fn
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return fn(*args, **kwargs)
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 582, in transform
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     tracer.run()
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 2451, in run
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     super().run()
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 893, in run
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     while self.step():
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 805, in step
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     self.dispatch_table[inst.opcode](self, inst)
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 2642, in RETURN_VALUE
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     self._return(inst)
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 2627, in _return
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     self.output.compile_subgraph(
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1098, in compile_subgraph
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     self.compile_and_call_fx_graph(tx, list(reversed(stack_values)), root)
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.10/contextlib.py", line 79, in inner
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1318, in compile_and_call_fx_graph
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     compiled_fn = self.call_user_compiler(gm)
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1409, in call_user_compiler
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1390, in call_user_compiler
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/repro/after_dynamo.py", line 129, in __call__
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     compiled_gm = compiler_fn(gm, example_inputs)
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/__init__.py", line 1951, in __call__
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return compile_fx(model_, inputs_, config_patches=self.config)
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.10/contextlib.py", line 79, in inner
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 1261, in compile_fx
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return compile_fx(
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.10/contextlib.py", line 79, in inner
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 1505, in compile_fx
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return aot_autograd(
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/backends/common.py", line 69, in __call__
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/aot_autograd.py", line 954, in aot_module_simplified
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     compiled_fn, _ = create_aot_dispatcher_function(
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/aot_autograd.py", line 687, in create_aot_dispatcher_function
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     compiled_fn, fw_metadata = compiler_fn(
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/_aot_autograd/jit_compile_runtime_wrappers.py", line 168, in aot_dispatch_base
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     compiled_fw = compiler(fw_module, updated_flat_args)
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 1410, in fw_compiler_base
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return inner_compile(
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.10/contextlib.py", line 79, in inner
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/repro/after_aot.py", line 84, in debug_wrapper
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/debug.py", line 304, in inner
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return fn(*args, **kwargs)
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.10/contextlib.py", line 79, in inner
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.10/contextlib.py", line 79, in inner
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 527, in compile_fx_inner
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     compiled_graph = fx_codegen_and_compile(
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/lib/python3.10/contextlib.py", line 79, in inner
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return func(*args, **kwds)
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 831, in fx_codegen_and_compile
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     compiled_fn = graph.compile_to_fn()
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/graph.py", line 1751, in compile_to_fn
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return self.compile_to_module().call
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/graph.py", line 1680, in compile_to_module
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/graph.py", line 1636, in codegen
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     self.scheduler = Scheduler(self.buffers)
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 231, in time_wrapper
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     r = func(*args, **kwargs)
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 1364, in __init__
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 1364, in <listcomp>
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 1462, in create_scheduler_node
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     return SchedulerNode(self, node)
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 731, in __init__
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     self._compute_attrs()
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 742, in _compute_attrs
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     group_fn = self.scheduler.get_backend(self.node.get_device()).group_fn
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 2663, in get_backend
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     self.backends[device] = self.create_backend(device)
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 2651, in create_backend
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]     raise RuntimeError(
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009] RuntimeError: Found Tesla P100-PCIE-16GB which is too old to be supported by the triton GPU compiler, which is used as the backend. Triton only supports devices of CUDA Capability >= 7.0, but your device is of CUDA capability 6.0
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W1226 07:37:01.049000 135376723240512 torch/_dynamo/convert_frame.py:1009]
# 🚀Animating... ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━  41% 0:01:11

# %%
# clear
# !rm /kaggle/working/LivePortrait/animations/*
# Out:
# rm: cannot remove '/kaggle/working/LivePortrait/animations/*': No such file or directory
