# %%
env_CN=0
if env_CN==1:
    git config --global url."https://mirror.ghproxy.com/https://github.com/".insteadOf https://github.com/
    export HF_ENDPOINT=https://hf-mirror.com
    # export HF_ENDPOINT=https://hf-api.gitee.com

# %%
# !nvcc --version
# !nvidia-smi

# %%
# !git clone https://github.com/BadToBest/EchoMimic
# Out:
# Cloning into 'EchoMimic'...
# remote: Enumerating objects: 556, done.
# remote: Counting objects: 100% (116/116), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 556 (delta 104), reused 83 (delta 83), pack-reused 440 (from 1)
# Receiving objects: 100% (556/556), 22.14 MiB | 19.68 MiB/s, done.
# Resolving deltas: 100% (123/123), done.

# %%
# %cd /kaggle/working/EchoMimic
# !git fetch origin pull/114/head:cv2-fix
# !git checkout -- webgui.py
# !git checkout cv2-fix
# !git checkout .
# !git pull
# !git lfs install
# Out:
# /kaggle/working/EchoMimic
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (2/2), done.
# remote: Total 3 (delta 2), reused 2 (delta 2), pack-reused 1 (from 1)
# Unpacking objects: 100% (3/3), 1018 bytes | 1018.00 KiB/s, done.
# From https://github.com/BadToBest/EchoMimic
#  * [new ref]         refs/pull/114/head -> cv2-fix
# Switched to branch 'cv2-fix'
# Updated 0 paths from the index
# There is no tracking information for the current branch.
# Please specify which branch you want to merge with.
# See git-pull(1) for details.
#
#     git pull <remote> <branch>
#
# If you wish to set tracking information for this branch you can do so with:
#
#     git branch --set-upstream-to=origin/<branch> cv2-fix
#
# Updated git hooks.
# Git LFS initialized.

# %% [markdown]
# # reboot

# %%
# %cd /kaggle/working/EchoMimic
# !pip install -r requirements.txt
# Out:
# /kaggle/working/EchoMimic
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.3/388.3 kB 20.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 9.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 57.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 15.3 MB/s eta 0:00:0000:01:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 50.3 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 MB 2.1 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.9 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 83.4 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 69.2 MB/s eta 0:00:00:00:0100:01
# ...

# %%
# !pip install huggingface_hub  hf_transfer
# !npm install -g localtunnel
import os
os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "1"
from huggingface_hub import snapshot_download, hf_hub_download

snapshot_download(
  repo_id="BadToBest/EchoMimic",
  local_dir="/opt/pretrained_weights",
)
# !git clone https://huggingface.co/BadToBest/EchoMimic pretrained_weights
# !ln -sf  /opt/pretrained_weights /kaggle/working/EchoMimic
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 56.6 MB/s eta 0:00:00a 0:00:01
# ...
# m#################.] / reify:yargs-parser: http fetch GET 200 https://registry.
# added 22 packages in 2s
#
# 3 packages are looking for funding
#   run `npm fund` for details
# npm notice
# npm notice New minor version of npm available! 10.5.0 -> 10.8.3
# npm notice Changelog: https://github.com/npm/cli/releases/tag/v10.8.3
# npm notice Run npm install -g npm@10.8.3 to update!
# npm notice
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# LICENSE:   0%|          | 0.00/11.4k [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/6.07k [00:00<?, ?B/s]
# whisper_tiny.pt:   0%|          | 0.00/75.6M [00:00<?, ?B/s]
# denoising_unet.pth:   0%|          | 0.00/3.40G [00:00<?, ?B/s]
# denoising_unet_acc.pth:   0%|          | 0.00/3.40G [00:00<?, ?B/s]
# denoising_unet_pose.pth:   0%|          | 0.00/3.40G [00:00<?, ?B/s]
# ...

# %%
import fileinput
print('found and replace')
# %cd /kaggle/working/EchoMimic

with fileinput.FileInput("webgui.py", inplace=True) as file:
    for line in file:
        if 'config_path = "./configs/prompts/animation.yaml"'in line:
            line = line.replace('config_path = "./configs/prompts/animation.yaml"',
                                'config_path = "./configs/prompts/animation_acc.yaml"')
        if "demo.launch" in line:
            line = line.replace('demo.launch(server_name=args.server_name, server_port=args.server_port, inbrowser=True)',
                                "demo.launch(share=False, server_name=args.server_name, server_port=args.server_port, inbrowser=True)")
        print(line, end='')
# Out:
# found and replace
# /kaggle/working/EchoMimic

# %%
# %cd /kaggle/working/EchoMimic
import subprocess
import urllib.request
from IPython.display import clear_output
clear_output()
print("The password/enpoint ip for localtunnel is:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
print("tts_tunnel is:")
subprocess.Popen(["lt", "--port", "3000"])
# !python -u webgui.py --server_port=3000
# Out:
# The password/enpoint ip for localtunnel is: 35.204.249.154
# tts_tunnel is:
# your url is: https://red-frogs-send.loca.lt
# /opt/conda/lib/python3.10/site-packages/diffusers/utils/outputs.py:63: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# /opt/conda/lib/python3.10/site-packages/diffusers/utils/outputs.py:63: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# /opt/conda/lib/python3.10/site-packages/diffusers/utils/outputs.py:63: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# please download ffmpeg-static and export to FFMPEG_PATH.
# ...
