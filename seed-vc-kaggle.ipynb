# %% [markdown]
# https://github.com/Plachtaa/seed-vc

# %%
# !git clone https://github.com/Plachtaa/seed-vc

# %cd seed-vc
# !git pull
# !pip install -r requirements.txt
# Out:
# Cloning into 'seed-vc'...
# remote: Enumerating objects: 426, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 426 (delta 36), reused 36 (delta 32), pack-reused 379 (from 1)
# Receiving objects: 100% (426/426), 62.89 MiB | 34.94 MiB/s, done.
# Resolving deltas: 100% (162/162), done.
# /kaggle/working/seed-vc
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu113
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-b3xst8sw
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-b3xst8sw
#   Resolved https://github.com/openai/whisper.git to commit 25639fc17ddc013d56c594bfbf7644f2185fad84
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 2.3 MB/s eta 0:00:00
# ...

# %%
# !pip install pyngrok
# !ngrok config add-authtoken 2Z6mxdfOQtkCd0cRypa73E1YTSi_3pByoAmFqphopTJ585RGu
# Out:
# ...
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
import fileinput
print('found and replace')

with fileinput.FileInput("app.py", inplace=True) as file:
    for line in file:
        if ").launch()" in line:
            line = line.replace(').launch()',
                                ").launch(share=False)")
        print(line, end='')
# Out:
# found and replace

# %%
import os
from pyngrok import ngrok
from IPython.display import clear_output, Javascript
ngrok.kill()
p_tunnel = ngrok.connect(7860)
clear_output()
print("Applio Url:", p_tunnel.public_url)
print("Save the link for later, this will take a while...")

# !python app.py
# Out:
# Applio Url: https://dbe2-34-168-26-182.ngrok-free.app
# Save the link for later, this will take a while...
# (…)whisper_small_wavenet_bigvgan_pruned.pth: 100%|█| 440M/440M [00:01<00:00, 223
# (…)_mel_seed_uvit_whisper_small_wavenet.yml: 100%|█| 2.26k/2.26k [00:00<00:00, 1
# /opt/conda/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:134: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# ...
