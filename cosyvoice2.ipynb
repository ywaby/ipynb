# %% [markdown]
# 不支持多gpu

# %% [markdown]
# ## run all after reboot

# %%
# %cd /kaggle/working/
# !git clone --depth=1 https://huggingface.co/spaces/FunAudioLLM/CosyVoice2-0.5B
# %cd CosyVoice2-0.5B
# !git pull
# !git lfs pull

# %%
# %cd /kaggle/working/CosyVoice2-0.5B
# !pip install -r requirements.txt
# !pip install gradio 
# !pip install huggingface_hub==0.25.2

# %%
# !python app.py
