# %% [markdown]
# [RVC github](https://github.com/RVC-Project/Retrieval-based-Voice-Conversion-WebUI)

# %%
# !git clone https://github.com/RVC-Project/Retrieval-based-Voice-Conversion-WebUI.git --depth=1

# %%
# %cd /kaggle/working/Retrieval-based-Voice-Conversion-WebUI
# !pip install -r requirements.txt -q

# %%
# !apt -y update -qq
# !apt -y install -qq aria2
# !pip install gdown
# !npm install -g localtunnel
# !pip install huggingface_hub  hf_transfer
import os
os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "1"
# Out:
# W: http://packages.cloud.google.com/apt/dists/gcsfuse-focal/InRelease: Key is stored in legacy trusted.gpg keyring (/etc/apt/trusted.gpg), see the DEPRECATION section in apt-key(8) for details.
# E: Repository 'http://packages.cloud.google.com/apt gcsfuse-focal InRelease' changed its 'Origin' value from 'gcsfuse-jessie' to 'gcsfuse-focal'
# E: Repository 'http://packages.cloud.google.com/apt gcsfuse-focal InRelease' changed its 'Label' value from 'gcsfuse-jessie' to 'gcsfuse-focal'
# W: https://packages.cloud.google.com/apt/dists/google-fast-socket/InRelease: Key is stored in legacy trusted.gpg keyring (/etc/apt/trusted.gpg), see the DEPRECATION section in apt-key(8) for details.
# The following additional packages will be installed:
#   libaria2-0 libc-ares2 libssh2-1
# The following NEW packages will be installed:
#   aria2 libaria2-0 libc-ares2 libssh2-1
# 0 upgraded, 4 newly installed, 0 to remove and 205 not upgraded.
# Need to get 1622 kB of archives.
# After this operation, 5817 kB of additional disk space will be used.
#
# 78Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 113701 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.18.1-1ubuntu0.22.04.3_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 87Progress: [  6%] [###.......................................................] 8Unpacking libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# 7Progress: [ 12%] [######....................................................] 8Selecting previously unselected package libssh2-1:amd64.
# Preparing to unpack .../libssh2-1_1.10.0-3_amd64.deb ...
# 7Progress: [ 18%] [##########................................................] 8Unpacking libssh2-1:amd64 (1.10.0-3) ...
# 7Progress: [ 24%] [#############.............................................] 8Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.36.0-1_amd64.deb ...
# 7Progress: [ 29%] [#################.........................................] 8Unpacking libaria2-0:amd64 (1.36.0-1) ...
# 7Progress: [ 35%] [####################......................................] 8Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.36.0-1_amd64.deb ...
# 7Progress: [ 41%] [#######################...................................] 8Unpacking aria2 (1.36.0-1) ...
# 7Progress: [ 47%] [###########################...............................] 8Setting up libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# 7Progress: [ 53%] [##############################............................] 87Progress: [ 59%] [##################################........................] 8Setting up libssh2-1:amd64 (1.10.0-3) ...
# 7Progress: [ 65%] [#####################################.....................] 87Progress: [ 71%] [########################################..................] 8Setting up libaria2-0:amd64 (1.36.0-1) ...
# 7Progress: [ 76%] [############################################..............] 87Progress: [ 82%] [###############################################...........] 8Setting up aria2 (1.36.0-1) ...
# 7Progress: [ 88%] [###################################################.......] 87Progress: [ 94%] [######################################################....] 8Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.1) ...
#
# m#################⠂) ⠧ reify:yargs-parser: http fetch GET 200 https://registry.
# added 22 packages in 1s
#
# 3 packages are looking for funding
#   run `npm fund` for details
# npm notice
# npm notice New major version of npm available! 9.5.0 -> 10.9.0
# npm notice Changelog: https://github.com/npm/cli/releases/tag/v10.9.0
# npm notice Run npm install -g npm@10.9.0 to update!
# npm notice
# Requirement already satisfied: huggingface_hub in /opt/conda/lib/python3.10/site-packages (0.25.2)
# Collecting hf_transfer
#   Downloading hf_transfer-0.1.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 53.8 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (3.12.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (6.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (4.65.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (4.6.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.9->huggingface_hub) (3.0.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface_hub) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface_hub) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface_hub) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface_hub) (2023.5.7)
# Installing collected packages: hf_transfer
# Successfully installed hf_transfer-0.1.8

# %% [markdown]
# ## download weight

# %%
from huggingface_hub import snapshot_download, hf_hub_download
import os
hf_hub_download(repo_id="lj1995/VoiceConversionWebUI",filename="hubert_base.pt", local_dir="/kaggle/working/Retrieval-based-Voice-Conversion-WebUI/assets/hubert")
hf_hub_download(repo_id="lj1995/VoiceConversionWebUI",filename="rmvpe.pt", local_dir="/kaggle/working/Retrieval-based-Voice-Conversion-WebUI/assets/rmvpe")
snapshot_download(repo_id="lj1995/VoiceConversionWebUI",allow_patterns=["uvr5_weights/*"], local_dir="/kaggle/working/Retrieval-based-Voice-Conversion-WebUI/assets")
snapshot_download(repo_id="lj1995/VoiceConversionWebUI",allow_patterns=["pretrained_v2/*"], local_dir="/kaggle/working/Retrieval-based-Voice-Conversion-WebUI/assets")
# snapshot_download(repo_id="lj1995/VoiceConversionWebUI",allow_patterns=["pretrained/*"], local_dir="/kaggle/working/Retrieval-based-Voice-Conversion-WebUI/assets")
# Out:
# [Errno 2] No such file or directory: '/kaggle/working/ComfyUI'
# /kaggle/working/Retrieval-based-Voice-Conversion-WebUI
# hubert_base.pt:   0%|          | 0.00/190M [00:00<?, ?B/s]
# rmvpe.pt:   0%|          | 0.00/181M [00:00<?, ?B/s]
# (…)-äººå£°vocals+éäººå£°instrumentals.pth:   0%|          | 0.00/63.5M [00:00<?, ?B/s]
# HP2_all_vocals.pth:   0%|          | 0.00/63.5M [00:00<?, ?B/s]
# HP3_all_vocals.pth:   0%|          | 0.00/63.5M [00:00<?, ?B/s]
# (…)å¾äººå£°vocals+å¶ä»instrumentals.pth:   0%|          | 0.00/63.5M [00:00<?, ?B/s]
# HP5_only_main_vocal.pth:   0%|          | 0.00/63.5M [00:00<?, ?B/s]
# VR-DeEchoAggressive.pth:   0%|          | 0.00/63.7M [00:00<?, ?B/s]
# VR-DeEchoDeReverb.pth:   0%|          | 0.00/112M [00:00<?, ?B/s]
# VR-DeEchoNormal.pth:   0%|          | 0.00/63.7M [00:00<?, ?B/s]
# vocals.onnx:   0%|          | 0.00/66.8M [00:00<?, ?B/s]
# D32k.pth:   0%|          | 0.00/143M [00:00<?, ?B/s]
# D40k.pth:   0%|          | 0.00/143M [00:00<?, ?B/s]
# D48k.pth:   0%|          | 0.00/143M [00:00<?, ?B/s]
# G32k.pth:   0%|          | 0.00/73.8M [00:00<?, ?B/s]
# G40k.pth:   0%|          | 0.00/73.0M [00:00<?, ?B/s]
# G48k.pth:   0%|          | 0.00/75.3M [00:00<?, ?B/s]
# f0D32k.pth:   0%|          | 0.00/143M [00:00<?, ?B/s]
# f0D40k.pth:   0%|          | 0.00/143M [00:00<?, ?B/s]
# f0D48k.pth:   0%|          | 0.00/143M [00:00<?, ?B/s]
# f0G32k.pth:   0%|          | 0.00/74.0M [00:00<?, ?B/s]
# f0G40k.pth:   0%|          | 0.00/73.1M [00:00<?, ?B/s]
# f0G48k.pth:   0%|          | 0.00/75.5M [00:00<?, ?B/s]
# '/kaggle/working/Retrieval-based-Voice-Conversion-WebUI/assets'

# %% [markdown]
# ## reboot run below

# %%
# %cd /kaggle/working/Retrieval-based-Voice-Conversion-WebUI
# branch
# !git checkout .
## update
# !git pull

# !pip install -r requirements.txt
# Out:
# /kaggle/working/Retrieval-based-Voice-Conversion-WebUI
# Updated 218 paths from the index
# Already up to date.
# Ignoring onnxruntime: markers 'sys_platform == "darwin"' don't match your environment
# Collecting aria2 (from -r requirements.txt (line 1))
#   Downloading aria2-0.0.1b0-py3-none-manylinux_2_17_x86_64.whl (5.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 45.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: joblib>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (1.2.0)
# Collecting numba==0.56.4 (from -r requirements.txt (line 3))
#   Downloading numba-0.56.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 74.3 MB/s eta 0:00:00:00:01
# Requirement already satisfied: numpy==1.23.5 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (1.23.5)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (1.11.1)
# Collecting librosa==0.9.1 (from -r requirements.txt (line 6))
#   Downloading librosa-0.9.1-py3-none-any.whl (213 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.1/213.1 kB 19.3 MB/s eta 0:00:00
# Collecting llvmlite==0.39.0 (from -r requirements.txt (line 7))
#   Downloading llvmlite-0.39.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.6/34.6 MB 38.5 MB/s eta 0:00:0000:0100:01
# Collecting fairseq==0.12.2 (from -r requirements.txt (line 8))
#   Downloading fairseq-0.12.2.tar.gz (9.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 85.9 MB/s eta 0:00:00:00:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting faiss-cpu==1.7.3 (from -r requirements.txt (line 9))
#   Downloading faiss_cpu-1.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 68.1 MB/s eta 0:00:0000:0100:01
# Collecting gradio==3.34.0 (from -r requirements.txt (line 10))
#   Downloading gradio-3.34.0-py3-none-any.whl (20.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 53.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: Cython in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 11)) (0.29.35)
# Requirement already satisfied: pydub>=0.25.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 12)) (0.25.1)
# Requirement already satisfied: soundfile>=0.12.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 13)) (0.12.1)
# Collecting ffmpeg-python>=0.2.0 (from -r requirements.txt (line 14))
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: tensorboardX in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 15)) (2.6)
# Requirement already satisfied: Jinja2>=3.1.2 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 16)) (3.1.2)
# Requirement already satisfied: json5 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 17)) (0.9.14)
# Requirement already satisfied: Markdown in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 18)) (3.4.3)
# Requirement already satisfied: matplotlib>=3.7.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 19)) (3.7.1)
# Requirement already satisfied: matplotlib-inline>=0.1.3 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 20)) (0.1.6)
# Collecting praat-parselmouth>=0.4.2 (from -r requirements.txt (line 21))
#   Downloading praat_parselmouth-0.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (10.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 84.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: Pillow>=9.1.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 22)) (9.5.0)
# Collecting resampy>=0.4.2 (from -r requirements.txt (line 23))
#   Downloading resampy-0.4.3-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 84.7 MB/s eta 0:00:00:00:01
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 24)) (1.2.2)
# Requirement already satisfied: tensorboard in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 25)) (2.12.3)
# Requirement already satisfied: tqdm>=4.63.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 26)) (4.65.0)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 27)) (6.3.2)
# Requirement already satisfied: Werkzeug>=2.2.3 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 28)) (2.3.6)
# Requirement already satisfied: uc-micro-py>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 29)) (1.0.2)
# Requirement already satisfied: sympy>=1.11.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 30)) (1.12)
# Requirement already satisfied: tabulate>=0.8.10 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 31)) (0.9.0)
# Requirement already satisfied: PyYAML>=6.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 32)) (6.0)
# Requirement already satisfied: pyasn1>=0.4.8 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 33)) (0.4.8)
# Collecting pyasn1-modules>=0.2.8 (from -r requirements.txt (line 34))
#   Downloading pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.5/181.5 kB 20.0 MB/s eta 0:00:00
# Requirement already satisfied: fsspec>=2022.11.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 35)) (2023.6.0)
# Requirement already satisfied: absl-py>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 36)) (1.4.0)
# Requirement already satisfied: audioread in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 37)) (3.0.0)
# Requirement already satisfied: uvicorn>=0.21.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 38)) (0.22.0)
# Requirement already satisfied: colorama>=0.4.5 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 39)) (0.4.6)
# Collecting pyworld==0.3.2 (from -r requirements.txt (line 40))
#   Downloading pyworld-0.3.2.tar.gz (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.4/214.4 kB 22.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting httpx (from -r requirements.txt (line 41))
#   Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 8.0 MB/s eta 0:00:00
# Collecting onnxruntime-gpu (from -r requirements.txt (line 43))
#   Downloading onnxruntime_gpu-1.19.2-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (226.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.2/226.2 MB 5.6 MB/s eta 0:00:0000:0100:01
# Collecting torchcrepe==0.0.20 (from -r requirements.txt (line 44))
#   Downloading torchcrepe-0.0.20-py3-none-any.whl (72.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.3/72.3 MB 18.2 MB/s eta 0:00:0000:0100:01
# Collecting fastapi==0.88 (from -r requirements.txt (line 45))
#   Downloading fastapi-0.88.0-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 5.8 MB/s eta 0:00:00
# Collecting torchfcpe (from -r requirements.txt (line 46))
#   Downloading torchfcpe-0.0.4-py3-none-any.whl (40.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.2/40.2 MB 30.6 MB/s eta 0:00:0000:0100:01
# Collecting ffmpy==0.3.1 (from -r requirements.txt (line 47))
#   Downloading ffmpy-0.3.1.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dotenv>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 48)) (1.0.0)
# Collecting av (from -r requirements.txt (line 49))
#   Downloading av-13.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.1/33.1 MB 40.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from numba==0.56.4->-r requirements.txt (line 3)) (59.8.0)
# Requirement already satisfied: decorator>=4.0.10 in /opt/conda/lib/python3.10/site-packages (from librosa==0.9.1->-r requirements.txt (line 6)) (5.1.1)
# Requirement already satisfied: pooch>=1.0 in /opt/conda/lib/python3.10/site-packages (from librosa==0.9.1->-r requirements.txt (line 6)) (1.6.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from librosa==0.9.1->-r requirements.txt (line 6)) (21.3)
# Requirement already satisfied: cffi in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2->-r requirements.txt (line 8)) (1.15.1)
# Collecting hydra-core<1.1,>=1.0.7 (from fairseq==0.12.2->-r requirements.txt (line 8))
#   Downloading hydra_core-1.0.7-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 11.7 MB/s eta 0:00:00
# Collecting omegaconf<2.1 (from fairseq==0.12.2->-r requirements.txt (line 8))
#   Downloading omegaconf-2.0.6-py3-none-any.whl (36 kB)
# Requirement already satisfied: regex in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2->-r requirements.txt (line 8)) (2023.6.3)
# Collecting sacrebleu>=1.4.12 (from fairseq==0.12.2->-r requirements.txt (line 8))
#   Downloading sacrebleu-2.4.3-py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.0/104.0 kB 13.3 MB/s eta 0:00:00
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2->-r requirements.txt (line 8)) (2.0.0)
# Collecting bitarray (from fairseq==0.12.2->-r requirements.txt (line 8))
#   Downloading bitarray-3.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (278 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.3/278.3 kB 26.2 MB/s eta 0:00:00
# Requirement already satisfied: torchaudio>=0.8.0 in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2->-r requirements.txt (line 8)) (2.0.1)
# Requirement already satisfied: aiofiles in /opt/conda/lib/python3.10/site-packages (from gradio==3.34.0->-r requirements.txt (line 10)) (22.1.0)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from gradio==3.34.0->-r requirements.txt (line 10)) (3.8.4)
# Requirement already satisfied: altair>=4.2.0 in /opt/conda/lib/python3.10/site-packages (from gradio==3.34.0->-r requirements.txt (line 10)) (5.0.1)
# Collecting gradio-client>=0.2.6 (from gradio==3.34.0->-r requirements.txt (line 10))
#   Downloading gradio_client-1.4.0-py3-none-any.whl (319 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.8/319.8 kB 28.1 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from gradio==3.34.0->-r requirements.txt (line 10)) (0.16.4)
# Requirement already satisfied: markdown-it-py[linkify]>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from gradio==3.34.0->-r requirements.txt (line 10)) (2.2.0)
# Requirement already satisfied: markupsafe in /opt/conda/lib/python3.10/site-packages (from gradio==3.34.0->-r requirements.txt (line 10)) (2.1.3)
# Collecting mdit-py-plugins<=0.3.3 (from gradio==3.34.0->-r requirements.txt (line 10))
#   Downloading mdit_py_plugins-0.3.3-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: orjson in /opt/conda/lib/python3.10/site-packages (from gradio==3.34.0->-r requirements.txt (line 10)) (3.9.1)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from gradio==3.34.0->-r requirements.txt (line 10)) (1.5.3)
# Requirement already satisfied: pydantic in /opt/conda/lib/python3.10/site-packages (from gradio==3.34.0->-r requirements.txt (line 10)) (1.10.10)
# Requirement already satisfied: pygments>=2.12.0 in /opt/conda/lib/python3.10/site-packages (from gradio==3.34.0->-r requirements.txt (line 10)) (2.15.1)
# Collecting python-multipart (from gradio==3.34.0->-r requirements.txt (line 10))
#   Downloading python_multipart-0.0.12-py3-none-any.whl (23 kB)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from gradio==3.34.0->-r requirements.txt (line 10)) (2.31.0)
# Collecting semantic-version (from gradio==3.34.0->-r requirements.txt (line 10))
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from gradio==3.34.0->-r requirements.txt (line 10)) (4.6.3)
# Requirement already satisfied: websockets>=10.0 in /opt/conda/lib/python3.10/site-packages (from gradio==3.34.0->-r requirements.txt (line 10)) (11.0.3)
# Collecting starlette==0.22.0 (from fastapi==0.88->-r requirements.txt (line 45))
#   Downloading starlette-0.22.0-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 kB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.4.0 in /opt/conda/lib/python3.10/site-packages (from starlette==0.22.0->fastapi==0.88->-r requirements.txt (line 45)) (3.7.0)
# Requirement already satisfied: future in /opt/conda/lib/python3.10/site-packages (from ffmpeg-python>=0.2.0->-r requirements.txt (line 14)) (0.18.3)
# Requirement already satisfied: protobuf<4,>=3.8.0 in /opt/conda/lib/python3.10/site-packages (from tensorboardX->-r requirements.txt (line 15)) (3.20.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 19)) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 19)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 19)) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 19)) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 19)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 19)) (2.8.2)
# Requirement already satisfied: traitlets in /opt/conda/lib/python3.10/site-packages (from matplotlib-inline>=0.1.3->-r requirements.txt (line 20)) (5.9.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->-r requirements.txt (line 24)) (3.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/conda/lib/python3.10/site-packages (from tensorboard->-r requirements.txt (line 25)) (1.51.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/lib/python3.10/site-packages (from tensorboard->-r requirements.txt (line 25)) (2.20.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /opt/conda/lib/python3.10/site-packages (from tensorboard->-r requirements.txt (line 25)) (1.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard->-r requirements.txt (line 25)) (0.7.1)
# Requirement already satisfied: wheel>=0.26 in /opt/conda/lib/python3.10/site-packages (from tensorboard->-r requirements.txt (line 25)) (0.40.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy>=1.11.1->-r requirements.txt (line 30)) (1.3.0)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.10/site-packages (from uvicorn>=0.21.1->-r requirements.txt (line 38)) (8.1.3)
# Requirement already satisfied: h11>=0.8 in /opt/conda/lib/python3.10/site-packages (from uvicorn>=0.21.1->-r requirements.txt (line 38)) (0.14.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from httpx->-r requirements.txt (line 41)) (2023.5.7)
# Collecting httpcore==1.* (from httpx->-r requirements.txt (line 41))
#   Downloading httpcore-1.0.6-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: idna in /opt/conda/lib/python3.10/site-packages (from httpx->-r requirements.txt (line 41)) (3.4)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from httpx->-r requirements.txt (line 41)) (1.3.0)
# Collecting coloredlogs (from onnxruntime-gpu->-r requirements.txt (line 43))
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /opt/conda/lib/python3.10/site-packages (from onnxruntime-gpu->-r requirements.txt (line 43)) (23.5.26)
# Collecting einops (from torchfcpe->-r requirements.txt (line 46))
#   Downloading einops-0.8.0-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 4.9 MB/s eta 0:00:00
# Collecting local-attention (from torchfcpe->-r requirements.txt (line 46))
#   Downloading local_attention-1.9.15-py3-none-any.whl (9.0 kB)
# Requirement already satisfied: jsonschema>=3.0 in /opt/conda/lib/python3.10/site-packages (from altair>=4.2.0->gradio==3.34.0->-r requirements.txt (line 10)) (4.17.3)
# Requirement already satisfied: toolz in /opt/conda/lib/python3.10/site-packages (from altair>=4.2.0->gradio==3.34.0->-r requirements.txt (line 10)) (0.12.0)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette==0.22.0->fastapi==0.88->-r requirements.txt (line 45)) (1.1.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi->fairseq==0.12.2->-r requirements.txt (line 8)) (2.21)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 25)) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 25)) (4.9)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 25)) (1.16.0)
# Requirement already satisfied: urllib3<2.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 25)) (1.26.15)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->-r requirements.txt (line 25)) (1.3.1)
# Collecting huggingface-hub>=0.14.0 (from gradio==3.34.0->-r requirements.txt (line 10))
#   Downloading huggingface_hub-0.25.2-py3-none-any.whl (436 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 436.6/436.6 kB 34.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.14.0->gradio==3.34.0->-r requirements.txt (line 10)) (3.12.2)
# Collecting antlr4-python3-runtime==4.8 (from hydra-core<1.1,>=1.0.7->fairseq==0.12.2->-r requirements.txt (line 8))
#   Downloading antlr4-python3-runtime-4.8.tar.gz (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.4/112.4 kB 12.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio==3.34.0->-r requirements.txt (line 10)) (0.1.0)
# Requirement already satisfied: linkify-it-py<3,>=1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio==3.34.0->-r requirements.txt (line 10)) (2.0.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->gradio==3.34.0->-r requirements.txt (line 10)) (2023.3)
# Requirement already satisfied: appdirs>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from pooch>=1.0->librosa==0.9.1->-r requirements.txt (line 6)) (1.4.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->gradio==3.34.0->-r requirements.txt (line 10)) (3.1.0)
# Collecting portalocker (from sacrebleu>=1.4.12->fairseq==0.12.2->-r requirements.txt (line 8))
#   Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.10/site-packages (from sacrebleu>=1.4.12->fairseq==0.12.2->-r requirements.txt (line 8)) (4.9.3)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->gradio==3.34.0->-r requirements.txt (line 10)) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->gradio==3.34.0->-r requirements.txt (line 10)) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/conda/lib/python3.10/site-packages (from aiohttp->gradio==3.34.0->-r requirements.txt (line 10)) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->gradio==3.34.0->-r requirements.txt (line 10)) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->gradio==3.34.0->-r requirements.txt (line 10)) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->gradio==3.34.0->-r requirements.txt (line 10)) (1.3.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime-gpu->-r requirements.txt (line 43))
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.0 MB/s eta 0:00:00
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->fairseq==0.12.2->-r requirements.txt (line 8)) (3.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio==3.34.0->-r requirements.txt (line 10)) (0.19.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->-r requirements.txt (line 25)) (3.2.2)
# Building wheels for collected packages: fairseq, pyworld, ffmpy, antlr4-python3-runtime
#   Building wheel for fairseq (pyproject.toml) ... done
#   Created wheel for fairseq: filename=fairseq-0.12.2-cp310-cp310-linux_x86_64.whl size=10414552 sha256=7f5aca32cd688389b09e0459deb31f2c89746a6496c65886bfdad9d8e55b5f06
#   Stored in directory: /root/.cache/pip/wheels/e4/35/55/9c66f65ec7c83fd6fbc2b9502a0ac81b2448a1196159dacc32
#   Building wheel for pyworld (pyproject.toml) ... done
#   Created wheel for pyworld: filename=pyworld-0.3.2-cp310-cp310-linux_x86_64.whl size=199921 sha256=2ab132427127d690d49142c2fbcae9f58309a2f02bdf10382213d4c99dd08d53
#   Stored in directory: /root/.cache/pip/wheels/35/48/7e/e25bdd25fda4326d47010c157709436a6ee7a1423e18a24195
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.1-py3-none-any.whl size=5596 sha256=e450596867fe33ed62e8703f9ec97b20bf2c4518b20e479eb527dca65771d417
#   Stored in directory: /root/.cache/pip/wheels/01/a6/d1/1c0828c304a4283b2c1639a09ad86f83d7c487ef34c6b4a1bf
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.8-py3-none-any.whl size=141229 sha256=32177a2e68bd108a1bf3e9513486f7a5126b4a214689fbaa3a19e90aa24c444b
#   Stored in directory: /root/.cache/pip/wheels/a7/20/bd/e1477d664f22d99989fd28ee1a43d6633dddb5cb9e801350d5
# Successfully built fairseq pyworld ffmpy antlr4-python3-runtime
# Installing collected packages: ffmpy, faiss-cpu, bitarray, antlr4-python3-runtime, semantic-version, pyworld, python-multipart, pyasn1-modules, praat-parselmouth, portalocker, omegaconf, llvmlite, humanfriendly, httpcore, ffmpeg-python, einops, av, aria2, starlette, sacrebleu, numba, mdit-py-plugins, hydra-core, huggingface-hub, httpx, coloredlogs, resampy, onnxruntime-gpu, local-attention, gradio-client, fastapi, torchfcpe, librosa, gradio, fairseq, torchcrepe
#   Attempting uninstall: pyasn1-modules
#     Found existing installation: pyasn1-modules 0.2.7
#     Uninstalling pyasn1-modules-0.2.7:
#       Successfully uninstalled pyasn1-modules-0.2.7
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.40.1
#     Uninstalling llvmlite-0.40.1:
#       Successfully uninstalled llvmlite-0.40.1
#   Attempting uninstall: starlette
#     Found existing installation: starlette 0.27.0
#     Uninstalling starlette-0.27.0:
#       Successfully uninstalled starlette-0.27.0
#   Attempting uninstall: numba
#     Found existing installation: numba 0.57.1
#     Uninstalling numba-0.57.1:
#       Successfully uninstalled numba-0.57.1
#   Attempting uninstall: mdit-py-plugins
#     Found existing installation: mdit-py-plugins 0.4.0
#     Uninstalling mdit-py-plugins-0.4.0:
#       Successfully uninstalled mdit-py-plugins-0.4.0
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.16.4
#     Uninstalling huggingface-hub-0.16.4:
#       Successfully uninstalled huggingface-hub-0.16.4
#   Attempting uninstall: fastapi
#     Found existing installation: fastapi 0.98.0
#     Uninstalling fastapi-0.98.0:
#       Successfully uninstalled fastapi-0.98.0
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.10.0.post2
#     Uninstalling librosa-0.10.0.post2:
#       Successfully uninstalled librosa-0.10.0.post2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 23.6.1 requires cupy-cuda11x>=12.0.0, which is not installed.
# cuml 23.6.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 23.6.1 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 23.6.1 requires numba>=0.57, but you have numba 0.56.4 which is incompatible.
# cudf 23.6.1 requires protobuf<4.22,>=4.21.6, but you have protobuf 3.20.3 which is incompatible.
# cuml 23.6.0 requires dask==2023.3.2, but you have dask 2023.7.0 which is incompatible.
# cuml 23.6.0 requires numba>=0.57, but you have numba 0.56.4 which is incompatible.
# dask-cuda 23.6.0 requires dask==2023.3.2, but you have dask 2023.7.0 which is incompatible.
# dask-cuda 23.6.0 requires numba>=0.57, but you have numba 0.56.4 which is incompatible.
# dask-cudf 23.6.1 requires dask==2023.3.2, but you have dask 2023.7.0 which is incompatible.
# kfp 2.0.1 requires google-cloud-storage<3,>=2.2.1, but you have google-cloud-storage 1.44.0 which is incompatible.
# raft-dask 23.6.2 requires dask==2023.3.2, but you have dask 2023.7.0 which is incompatible.
# raft-dask 23.6.2 requires numba>=0.57, but you have numba 0.56.4 which is incompatible.
# rmm 23.6.0 requires numba>=0.57, but you have numba 0.56.4 which is incompatible.
# Successfully installed antlr4-python3-runtime-4.8 aria2-0.0.1b0 av-13.1.0 bitarray-3.0.0 coloredlogs-15.0.1 einops-0.8.0 fairseq-0.12.2 faiss-cpu-1.7.3 fastapi-0.88.0 ffmpeg-python-0.2.0 ffmpy-0.3.1 gradio-3.34.0 gradio-client-1.4.0 httpcore-1.0.6 httpx-0.27.2 huggingface-hub-0.25.2 humanfriendly-10.0 hydra-core-1.0.7 librosa-0.9.1 llvmlite-0.39.0 local-attention-1.9.15 mdit-py-plugins-0.3.3 numba-0.56.4 omegaconf-2.0.6 onnxruntime-gpu-1.19.2 portalocker-2.10.1 praat-parselmouth-0.4.5 pyasn1-modules-0.3.0 python-multipart-0.0.12 pyworld-0.3.2 resampy-0.4.3 sacrebleu-2.4.3 semantic-version-2.10.0 starlette-0.22.0 torchcrepe-0.0.20 torchfcpe-0.0.4

# %%
# !pip3 install faiss-cpu==1.7.2 fairseq gradio==3.14.0 ffmpeg ffmpeg-python praat-parselmouth pyworld numpy==1.23.5 numba==0.56.4 librosa==0.9.2

# %%
# !apt -y update -qq
# !apt -y install -qq aria2
# !pip install gdown
# !npm install -g localtunnel
# !pip install huggingface_hub  hf_transfer
import os
os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "1"
# Out:
# W: http://packages.cloud.google.com/apt/dists/gcsfuse-focal/InRelease: Key is stored in legacy trusted.gpg keyring (/etc/apt/trusted.gpg), see the DEPRECATION section in apt-key(8) for details.
# E: Repository 'http://packages.cloud.google.com/apt gcsfuse-focal InRelease' changed its 'Origin' value from 'gcsfuse-jessie' to 'gcsfuse-focal'
# E: Repository 'http://packages.cloud.google.com/apt gcsfuse-focal InRelease' changed its 'Label' value from 'gcsfuse-jessie' to 'gcsfuse-focal'
# W: https://packages.cloud.google.com/apt/dists/google-fast-socket/InRelease: Key is stored in legacy trusted.gpg keyring (/etc/apt/trusted.gpg), see the DEPRECATION section in apt-key(8) for details.

# %%
# !pip list |grep numba
# !pip list |grep numpy
# !pip list |grep transformers
# !pip list |grep torch
# !pip list |grep cupy

# %% [markdown]
# ## Web UI

# %%
# %cd /kaggle/working/Retrieval-based-Voice-Conversion-WebUI
import subprocess
import urllib.request
print("The password/enpoint ip for localtunnel is:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
subprocess.Popen(["lt", "--port", "7865"])
# !python infer-web.py
# Out:
# /kaggle/working/Retrieval-based-Voice-Conversion-WebUI
# The password/enpoint ip for localtunnel is: 34.127.8.41
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 5
#       3 import urllib.request
#       4 print("The password/enpoint ip for localtunnel is:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
# ----> 5 subprocess.Popen(["lt", "--port", "7865"])
#       6 get_ipython().system('python infer-web.py')
#
# File /opt/conda/lib/python3.10/subprocess.py:971, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     967         if self.text_mode:
#     968             self.stderr = io.TextIOWrapper(self.stderr,
#     969                     encoding=encoding, errors=errors)
# --> 971     self._execute_child(args, executable, preexec_fn, close_fds,
#     972                         pass_fds, cwd, env,
#     973                         startupinfo, creationflags, shell,
#     974                         p2cread, p2cwrite,
#     975                         c2pread, c2pwrite,
#     976                         errread, errwrite,
#     977                         restore_signals,
#     978                         gid, gids, uid, umask,
#     979                         start_new_session)
#     980 except:
#     981     # Cleanup if the child failed starting.
#     982     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File /opt/conda/lib/python3.10/subprocess.py:1863, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1861     if errno_num != 0:
#    1862         err_msg = os.strerror(errno_num)
# -> 1863     raise child_exception_type(errno_num, err_msg, err_filename)
#    1864 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'lt'

# %% [markdown]
# ## cli convert

# %%
# %cd /kaggle/working/Retrieval-based-Voice-Conversion-WebUI
# !mkdir /kaggle/working/rvc_output
#f0up_key 变声
#f0method ["pm", "harvest", "dio", "rmvpe", "rmvpe_gpu"],选择音高提取算法:输入歌声可用pm提速,高质量语音但CPU差可用dio提速,harvest质量更好但慢,rmvpe效果最好且微吃CPU/GPU"
#input_path 输入的音频文件
#model_name 声库,assets/weights
#index_rate 检索特征占比
#filter_radius >=3则使用对harvest音高识别的结果使用中值滤波，数值为滤波半径，使用可以削弱哑音
#resample_sr 后处理重采样至最终采样率，0为不进行重采样
#rms_mix_rate 输入源音量包络替换输出音量包络融合比例，越靠近1越使用输出包络
# protect 保护清辅音和呼吸声，防止电音撕裂等artifact，拉满0.5不开启，调低加大保护力度但可能降低索引效果
#--index_path INDEX_PATH\ #特征检索库文件路径

# !python ./tools/infer_cli.py --f0up_key 0 \
    --input_path /kaggle/input/to-rvc/test.mp3\
    --f0method dio \
    --opt_path /kaggle/working/rvc_output/test.wav \
    --model_name rumeng/qiqi/qiqi.pth\
    --filter_radius 3 \
    --resample_sr 0  \
    --rms_mix_rate 0.25 \
    --protect 0.1 

from IPython.display import Audio
audio = Audio(filename='/kaggle/working/rvc_output/test.wav')
display(audio)

# %% [markdown]
# TRAIN
