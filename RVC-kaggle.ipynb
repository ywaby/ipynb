# %% [markdown]
# [RVC github](https://github.com/RVC-Project/Retrieval-based-Voice-Conversion-WebUI)

# %%
# !git clone https://github.com/RVC-Project/Retrieval-based-Voice-Conversion-WebUI.git --depth=1

# %%
# %cd /kaggle/working/Retrieval-based-Voice-Conversion-WebUI
# !pip install -r requirements.txt -q

# %%
# !apt -y update -qq
# !apt -y install -qq aria2
# !pip install gdown
# !npm install -g localtunnel
# !pip install huggingface_hub  hf_transfer
import os
os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "1"

# %% [markdown]
# ## download weight

# %%
# %cd /kaggle/working/ComfyUI

from huggingface_hub import snapshot_download, hf_hub_download
import os
hf_hub_download(repo_id="lj1995/VoiceConversionWebUI",filename="hubert_base.pt", local_dir="/kaggle/working/Retrieval-based-Voice-Conversion-WebUI/")
hf_hub_download(repo_id="lj1995/VoiceConversionWebUI",filename="rmvpe.pt", local_dir="/kaggle/working/Retrieval-based-Voice-Conversion-WebUI")
snapshot_download(repo_id="lj1995/VoiceConversionWebUI",allow_patterns=["uvr5_weights/*"], local_dir="/kaggle/working/Retrieval-based-Voice-Conversion-WebUI")
snapshot_download(repo_id="lj1995/VoiceConversionWebUI",allow_patterns=["pretrained_v2/*"], local_dir="/kaggle/working/Retrieval-based-Voice-Conversion-WebUI/assets")
# snapshot_download(repo_id="lj1995/VoiceConversionWebUI",allow_patterns=["pretrained/*"], local_dir="/kaggle/working/Retrieval-based-Voice-Conversion-WebUI/assets")

# %% [markdown]
# ## reboot run below

# %%
# %cd /kaggle/working/Retrieval-based-Voice-Conversion-WebUI
# branch
# !git checkout .
## update
# !git pull

# !pip install -r requirements.txt
# Out:
# /kaggle/working/Retrieval-based-Voice-Conversion-WebUI
# Updated 199 paths from the index
# remote: Enumerating objects: 616, done.
# remote: Counting objects: 100% (402/402), done.
# remote: Compressing objects: 100% (93/93), done.
# remote: Total 616 (delta 331), reused 354 (delta 309), pack-reused 214 (from 1)
# Receiving objects: 100% (616/616), 531.13 KiB | 17.13 MiB/s, done.
# Resolving deltas: 100% (377/377), completed with 67 local objects.
# From https://github.com/RVC-Project/Retrieval-based-Voice-Conversion-WebUI
#    ff093ad..3548b4f  main       -> origin/main
#  * [new tag]         1.0.230410 -> 1.0.230410
#  * [new tag]         1.1.230416 -> 1.1.230416
#  * [new tag]         1.2.230428 -> 1.2.230428
#  * [new tag]         2.0.230528 -> 2.0.230528
#  * [new tag]         2.0.230618 -> 2.0.230618
#  * [new tag]         2.1.230814 -> 2.1.230814
#  * [new tag]         2.2.231006 -> 2.2.231006
# Updating ff093ad..3548b4f
# Fast-forward
#  .env                                               |    1 +
#  .github/PULL_REQUEST_TEMPLATE.md                   |   14 +-
#  .github/workflows/unitest.yml                      |    2 +-
#  .gitignore                                         |    5 +
#  CONTRIBUTING.md                                    |   11 +
#  Dockerfile                                         |    1 +
#  README.md                                          |  174 +-
#  Retrieval_based_Voice_Conversion_WebUI.ipynb       |    2 +-
#  Retrieval_based_Voice_Conversion_WebUI_v2.ipynb    |    2 +-
#  api_231006.py                                      |  440 ++
#  api_240604.py                                      |  565 +++
#  assets/indices/.gitignore                          |    2 +
#  configs/config.json                                |    2 +-
#  configs/config.py                                  |   29 +-
#  configs/inuse/.gitignore                           |    4 +
#  configs/inuse/v1/.gitignore                        |    2 +
#  configs/inuse/v2/.gitignore                        |    2 +
#  docs/en/README.en.md                               |  107 +-
#  docs/fr/README.fr.md                               |   68 +-
#  docs/jp/Changelog_JA.md                            |  123 +
#  docs/jp/README.ja.md                               |  254 +-
#  docs/jp/faq_ja.md                                  |  122 +
#  docs/kr/Changelog_KO.md                            |   24 +-
#  docs/kr/README.ko.han.md                           |    2 +-
#  docs/kr/README.ko.md                               |  223 +-
#  docs/kr/faq_ko.md                                  |  130 +
#  docs/pt/Changelog_pt.md                            |  105 +
#  docs/pt/README.pt.md                               |  193 +
#  docs/pt/faiss_tips_pt.md                           |  102 +
#  docs/pt/faq_pt.md                                  |  224 +
#  docs/pt/training_tips_pt.md                        |   65 +
#  docs/tr/README.tr.md                               |    2 +-
#  gui_v1.py                                          | 1944 ++++----
#  i18n/locale/en_US.json                             |   15 +-
#  i18n/locale/es_ES.json                             |    9 +-
#  i18n/locale/fr_FR.json                             |    9 +-
#  i18n/locale/it_IT.json                             |    9 +-
#  i18n/locale/ja_JP.json                             |    9 +-
#  i18n/locale/ko_KR.json                             |  137 +
#  i18n/locale/pt_BR.json                             |  137 +
#  i18n/locale/ru_RU.json                             |    9 +-
#  i18n/locale/tr_TR.json                             |    9 +-
#  i18n/locale/zh_CN.json                             |   11 +-
#  i18n/locale/zh_HK.json                             |    9 +-
#  i18n/locale/zh_SG.json                             |    9 +-
#  i18n/locale/zh_TW.json                             |    9 +-
#  infer-web.py                                       |  215 +-
#  infer/lib/audio.py                                 |   67 +-
#  infer/lib/infer_pack/models.py                     |  436 +-
#  infer/lib/infer_pack/models_onnx.py                |   10 +-
#  .../modules/F0Predictor/HarvestF0Predictor.py      |    2 +-
#  infer/lib/jit/get_synthesizer.py                   |    1 +
#  infer/lib/rmvpe.py                                 |   12 +-
#  infer/lib/rtrvc.py                                 |  461 ++
#  infer/lib/train/mel_processing.py                  |    9 +-
#  infer/lib/train/utils.py                           |   13 +-
#  infer/lib/uvr5_pack/lib_v5/spec_utils.py           |   42 +-
#  infer/modules/ipex/attention.py                    |  114 +-
#  infer/modules/ipex/hijacks.py                      |   42 +-
#  infer/modules/train/extract/extract_f0_print.py    |    2 +-
#  infer/modules/train/extract/extract_f0_rmvpe.py    |    2 +-
#  .../modules/train/extract/extract_f0_rmvpe_dml.py  |    2 +-
#  infer/modules/train/extract_feature_print.py       |   21 +-
#  infer/modules/train/preprocess.py                  |   11 +-
#  infer/modules/train/train.py                       |   11 +-
#  infer/modules/uvr5/mdxnet.py                       |    4 +-
#  infer/modules/uvr5/modules.py                      |    2 +-
#  infer/modules/uvr5/vr.py                           |   40 +-
#  infer/modules/vc/modules.py                        |   22 +-
#  poetry.lock                                        | 5248 +++++++++++---------
#  pyproject.toml                                     |   92 +-
#  requirements-amd.txt                               |    5 +-
#  requirements-dml.txt                               |    5 +-
#  requirements-ipex.txt                              |    7 +-
#  requirements-py311.txt                             |   48 +
#  requirements-win-for-realtime_vc_gui-dml.txt       |    5 +-
#  requirements-win-for-realtime_vc_gui.txt           |    3 +-
#  requirements.txt                                   |    2 +
#  run.sh                                             |   29 +-
#  tools/app.py                                       |   28 +-
#  tools/dlmodels.bat                                 |   16 +-
#  tools/dlmodels.sh                                  |  633 +--
#  tools/infer/infer-pm-index256.py                   |    1 +
#  tools/infer/train-index-v2.py                      |    1 +
#  tools/infer/train-index.py                         |    1 +
#  tools/onnx_inference_demo.py                       |    4 +-
#  tools/rvc_for_realtime.py                          |  866 ++--
#  tools/torchgate/__init__.py                        |    1 +
#  venv.sh                                            |    2 +
#  89 files changed, 8717 insertions(+), 5148 deletions(-)
#  create mode 100644 CONTRIBUTING.md
#  create mode 100644 api_231006.py
#  create mode 100644 api_240604.py
#  create mode 100644 assets/indices/.gitignore
#  create mode 100644 configs/inuse/.gitignore
#  create mode 100644 configs/inuse/v1/.gitignore
#  create mode 100644 configs/inuse/v2/.gitignore
#  create mode 100644 docs/jp/Changelog_JA.md
#  create mode 100644 docs/jp/faq_ja.md
#  create mode 100644 docs/kr/faq_ko.md
#  create mode 100644 docs/pt/Changelog_pt.md
#  create mode 100644 docs/pt/README.pt.md
#  create mode 100644 docs/pt/faiss_tips_pt.md
#  create mode 100644 docs/pt/faq_pt.md
#  create mode 100644 docs/pt/training_tips_pt.md
#  create mode 100644 i18n/locale/ko_KR.json
#  create mode 100644 i18n/locale/pt_BR.json
#  create mode 100644 infer/lib/rtrvc.py
#  create mode 100644 requirements-py311.txt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/IPython/utils/_process_posix.py:148, in ProcessHandler.system(self, cmd)
#     147 else:
# --> 148     child = pexpect.spawn(self.sh, args=['-c', cmd])  # Vanilla Pexpect
#     149 flush = sys.stdout.flush
#
# File /opt/conda/lib/python3.10/site-packages/pexpect/pty_spawn.py:205, in spawn.__init__(self, command, args, timeout, maxread, searchwindowsize, logfile, cwd, env, ignore_sighup, echo, preexec_fn, encoding, codec_errors, dimensions, use_poll)
#     204 else:
# --> 205     self._spawn(command, args, preexec_fn, dimensions)
#     206 self.use_poll = use_poll
#
# File /opt/conda/lib/python3.10/site-packages/pexpect/pty_spawn.py:303, in spawn._spawn(self, command, args, preexec_fn, dimensions)
#     300     self.args = [a if isinstance(a, bytes) else a.encode(self.encoding)
#     301                  for a in self.args]
# --> 303 self.ptyproc = self._spawnpty(self.args, env=self.env,
#     304                              cwd=self.cwd, **kwargs)
#     306 self.pid = self.ptyproc.pid
#
# File /opt/conda/lib/python3.10/site-packages/pexpect/pty_spawn.py:315, in spawn._spawnpty(self, args, **kwargs)
#     314 '''Spawn a pty and return an instance of PtyProcess.'''
# --> 315 return ptyprocess.PtyProcess.spawn(args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/ptyprocess/ptyprocess.py:315, in PtyProcess.spawn(cls, argv, cwd, env, echo, preexec_fn, dimensions, pass_fds)
#     314 os.close(exec_err_pipe_write)
# --> 315 exec_err_data = os.read(exec_err_pipe_read, 4096)
#     316 os.close(exec_err_pipe_read)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[1], line 7
#       4 ## update
#       5 get_ipython().system('git pull')
# ----> 7 get_ipython().system('pip install -r requirements.txt')
#
# File /opt/conda/lib/python3.10/site-packages/ipykernel/zmqshell.py:649, in ZMQInteractiveShell.system_piped(self, cmd)
#     647         self.user_ns["_exit_code"] = system(cmd)
#     648 else:
# --> 649     self.user_ns["_exit_code"] = system(self.var_expand(cmd, depth=1))
#
# File /opt/conda/lib/python3.10/site-packages/IPython/utils/_process_posix.py:164, in ProcessHandler.system(self, cmd)
#     159         out_size = len(child.before)
#     160 except KeyboardInterrupt:
#     161     # We need to send ^C to the process.  The ascii code for '^C' is 3
#     162     # (the character is known as ETX for 'End of Text', see
#     163     # curses.ascii.ETX).
# --> 164     child.sendline(chr(3))
#     165     # Read and print any more output the program might produce on its
#     166     # way out.
#     167     try:
#
# UnboundLocalError: local variable 'child' referenced before assignment

# %%
# !pip3 install faiss-cpu==1.7.2 fairseq gradio==3.14.0 ffmpeg ffmpeg-python praat-parselmouth pyworld numpy==1.23.5 numba==0.56.4 librosa==0.9.2

# %%
# !apt -y update -qq
# !apt -y install -qq aria2
# !pip install gdown
# !npm install -g localtunnel
# !pip install huggingface_hub  hf_transfer
import os
os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "1"

# %%
# !pip list |grep numba
# !pip list |grep numpy
# !pip list |grep transformers
# !pip list |grep torch
# !pip list |grep cupy

# %% [markdown]
# ## Web UI

# %%
# %cd /kaggle/working/ComfyUI
import subprocess
import urllib.request
print("The password/enpoint ip for localtunnel is:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
subprocess.Popen(["lt", "--port", "7865"])
# !python infer-web.py

# %% [markdown]
# ## cli convert

# %%
# %cd /kaggle/working/Retrieval-based-Voice-Conversion-WebUI
# !mkdir /kaggle/working/rvc_output
#f0up_key 变声
#f0method ["pm", "harvest", "dio", "rmvpe", "rmvpe_gpu"],选择音高提取算法:输入歌声可用pm提速,高质量语音但CPU差可用dio提速,harvest质量更好但慢,rmvpe效果最好且微吃CPU/GPU"
#input_path 输入的音频文件
#model_name 声库,assets/weights
#index_rate 检索特征占比
#filter_radius >=3则使用对harvest音高识别的结果使用中值滤波，数值为滤波半径，使用可以削弱哑音
#resample_sr 后处理重采样至最终采样率，0为不进行重采样
#rms_mix_rate 输入源音量包络替换输出音量包络融合比例，越靠近1越使用输出包络
# protect 保护清辅音和呼吸声，防止电音撕裂等artifact，拉满0.5不开启，调低加大保护力度但可能降低索引效果
#--index_path INDEX_PATH\ #特征检索库文件路径

# !python ./tools/infer_cli.py --f0up_key 0 \
    --input_path /kaggle/input/to-rvc/test.mp3\
    --f0method dio \
    --opt_path /kaggle/working/rvc_output/test.wav \
    --model_name rumeng/qiqi/qiqi.pth\
    --filter_radius 3 \
    --resample_sr 0  \
    --rms_mix_rate 0.25 \
    --protect 0.1 

from IPython.display import Audio
audio = Audio(filename='/kaggle/working/rvc_output/test.wav')
display(audio)

# %% [markdown]
# TRAIN
